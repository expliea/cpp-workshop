// %% [markdown]
// ## Explicatis C++ Workshop 2023
// ---

// %% [markdown]
// ## Usage
// This Jupyter Notebook uses a C++ kernel based on the `cling` C++ interpreter and the `xeus` native implementation of the Jupyter protocol.
// <div style="background: #efffed;
//             border: 1px solid grey;
//             margin: 8px 0 8px 0;
//             text-align: center;
//             padding: 8px; ">
//     <i class="fa-play fa"
//        style="font-size: 40px;
//               line-height: 40px;
//               margin: 8px;
//               color: #444;">
//     </i>
//     <div>
//     To run the selected code cell, hit <pre style="background: #efffed">Shift + Enter</pre>
//     </div>
// </div>

// %% [markdown]
// ----
// C++ ist eine Systemprogrammiersprache, die nach Aussage ihres Erfinders Bjarne Stroustrup entwickelt wurde, um
//
// * ein "besseres C" zu sein
// * Datenabstraktion zu unterstützen
// * objektorientierte Programmierung zu unterstützen
// * generischen Programmierung zu unterstützen
//
// Obwohl ihre Syntax schwieriger oder komplexer sein kann als die neuerer Sprachen, ist sie weit verbreitet, weil sie zu nativen Befehlen kompiliert wird, die direkt vom Prozessor ausgeführt werden können, und eine enge Kontrolle über die Hardware bietet (wie C), während sie gleichzeitig High-Level-Funktionen wie generische Funktionen, Ausnahmen und Klassen bietet. Diese Kombination aus Geschwindigkeit und Funktionalität macht C++ zu einer der am weitesten verbreiteten Programmiersprachen.
//
// ---

// %% [markdown]
// Comparison to C
// ---

// %%
// C++ is _almost_ a superset of C and shares its basic syntax for
// variable declarations, primitive types, and functions.

// Just like in C, your program's entry point is a function called
// main with an integer return type.
// This value serves as the program's exit status.
// See https://en.wikipedia.org/wiki/Exit_status for more information.
int main(int argc, char** argv)
{
    // Command line arguments are passed in by argc and argv in the same way
    // they are in C.
    // argc indicates the number of arguments,
    // and argv is an array of C-style strings (char*)
    // representing the arguments.
    // The first argument is the name by which the program was called.
    // argc and argv can be omitted if you do not care about arguments,
    // giving the function signature of int main()

    // An exit status of 0 indicates success.
    return 0;
}

// However, C++ varies in some of the following ways:

// In C++, character literals are chars
sizeof('c') == sizeof(char) == 1;

// In C, character literals are ints
sizeof('c') == sizeof(int);


// C++ has strict prototyping
void func(); // function which accepts no arguments

// In C
void func(); // function which may accept any number of arguments

// Use nullptr instead of NULL in C++
int* ip = nullptr;

// C standard headers are available in C++.
// C headers end in .h, while
// C++ headers are prefixed with "c" and have no ".h" suffix.

// The C++ standard version:
#include <cstdio>

// The C standard version:
#include <stdio.h>

int main()
{
    printf("Hello, world!\n");
    return 0;
}

// %%
main()
// Out:
// Hello, world!
// 0

// %% [markdown]
// Comparison to C
// ---

// %%
// C++ supports function overloading
// provided each function takes different parameters.

void print(char const* myString)
{
    printf("String %s\n", myString);
}

// %%
void print(int myInt)
{
    printf("My int is %d", myInt);
}

// %%
print("Hello"); // Resolves to void print(const char*)
print(15); // Resolves to void print(int)
// Out:
// String Hello
// My int is 15

// %% [markdown]
// Default function arguments
// ---

// %%
// You can provide default arguments for a function
// if they are not provided by the caller.

void doSomethingWithInts(int a = 1, int b = 4)
{
    // Do something with the ints here
}

// %%
doSomethingWithInts();      // a = 1,  b = 4
doSomethingWithInts(20);    // a = 20, b = 4
doSomethingWithInts(20, 5); // a = 20, b = 5

// %%
// Default arguments must be at the end of the arguments list.
void invalidDeclaration(int a = 1, int b) // Error!
{
}

invalidDeclaration(1,2)
// Out:
// input_line_73:2:40: error: missing default argument on parameter 'b'
// void invalidDeclaration(int a = 1, int b) // Error!
//                                        ^
// Interpreter Error:

// %% [markdown]
// Namespaces
// ---
// Namespaces provide separate scopes for variables, functions and other declarations.
//
// Namespaces can be nested.

// %%
namespace First {
    namespace Nested {
        void foo()
        {
            printf("This is First::Nested::foo\n");
        }
    } // end namespace Nested
} // end namespace First

namespace Second {
    void foo()
    {
        printf("This is Second::foo\n");
    }
    void bar()
    {
        printf("This is Second::bar\n");
    }
}

void foo()
{
    printf("This is global foo\n");
}

int main()
{
    // Includes all symbols from namespace Second into the current scope. Note
    // that while bar() works, simply using foo() no longer works, since it is
    // now ambiguous whether we're calling the foo in namespace Second or the
    // top level.
    using namespace Second;

    bar(); // prints "This is Second::bar"
    Second::foo(); // prints "This is Second::foo"
    First::Nested::foo(); // prints "This is First::Nested::foo"
    ::foo(); // prints "This is global foo"
}

// %%
main()
// Out:
// This is Second::bar
// This is Second::foo
// This is First::Nested::foo
// This is global foo
// 0

// %% [markdown]
// Input/Output
// ---
// C++ input and output uses streams
//
// cin, cout, and cerr represent stdin, stdout, and stderr.
//
// << is the insertion operator and >> is the extraction operator.

// %%
#include <iostream> // Include for I/O streams

using namespace std; // Streams are in the std namespace (standard library)

int main()
{
   int myInt;

   // Prints to stdout (or terminal/screen)
   cout << "Enter your favorite number:\n";
   // Takes in input
   cin >> myInt;

   // cout can also be formatted
   cout << "Your favorite number is " << myInt << '\n';
   // prints "Your favorite number is <myInt>"

   cerr << "Used for error messages";
}
// Out:
// input_line_17:4:1: error: function definition is not allowed here
// {
// ^
// Interpreter Error:

// %% [markdown]
// Strings
// ---
// Strings in C++ are objects and have many member functions

// %%
#include <string>

using namespace std; // Strings are also in the namespace std (standard library)

string myString = "Hello";
string myOtherString = " World";

// + is used for concatenation.
cout << myString + myOtherString; // "Hello World"

cout << myString + " You"; // "Hello You"

// C++ strings are mutable.
myString.append(" Dog");
cout << myString; // "Hello Dog"
// Out:
// Hello WorldHello YouHello Dog
// @0x7fadb0791de0

// %% [markdown]
// References
// ---
// In addition to pointers like the ones in C, C++ has _references_.
//
// These are pointer types that cannot be reassigned once set and cannot be null.
//
// They also have the same syntax as the variable itself:
// * No * is needed for dereferencing and
// * & (address of) is not used for assignment.

// %%
using namespace std;

string foo = "I am foo";
string bar = "I am bar";

string& fooRef = foo; // This creates a reference to foo.
fooRef += ". Hi!"; // Modifies foo through the reference
cout << fooRef; // Prints "I am foo. Hi!"

// Doesn't reassign "fooRef". This is the same as "foo = bar", and
//   foo == "I am bar"
// after this line.
cout << &fooRef << endl; //Prints the address of foo
fooRef = bar;
cout << &fooRef << endl; //Still prints the address of foo
cout << fooRef;  // Prints "I am bar"

// The address of fooRef remains the same, i.e. it is still referring to foo.


const string& barRef = bar; // Create a const reference to bar.
// Like C, const values (and pointers and references) cannot be modified.
barRef += ". Hi!"; // Error, const references cannot be modified.

// Sidetrack: Before we talk more about references, we must introduce a concept
// called a temporary object. Suppose we have the following code:
string tempObjectFun() { ... }
string retVal = tempObjectFun();

// What happens in the second line is actually:
//   - a string object is returned from tempObjectFun
//   - a new string is constructed with the returned object as argument to the
//     constructor
//   - the returned object is destroyed
// The returned object is called a temporary object. Temporary objects are
// created whenever a function returns an object, and they are destroyed at the
// end of the evaluation of the enclosing expression (Well, this is what the
// standard says, but compilers are allowed to change this behavior. Look up
// "return value optimization" if you're into this kind of details). So in this
// code:
foo(bar(tempObjectFun()))

// assuming foo and bar exist, the object returned from tempObjectFun is
// passed to bar, and it is destroyed before foo is called.

// Now back to references. The exception to the "at the end of the enclosing
// expression" rule is if a temporary object is bound to a const reference, in
// which case its life gets extended to the current scope:

void constReferenceTempObjectFun() {
  // constRef gets the temporary object, and it is valid until the end of this
  // function.
  const string& constRef = tempObjectFun();
  ...
}

// Another kind of reference introduced in C++11 is specifically for temporary
// objects. You cannot have a variable of its type, but it takes precedence in
// overload resolution:

void someFun(string& s) { ... }  // Regular reference
void someFun(string&& s) { ... }  // Reference to temporary object

string foo;
someFun(foo);  // Calls the version with regular reference
someFun(tempObjectFun());  // Calls the version with temporary reference

// For example, you will see these two versions of constructors for
// std::basic_string:
basic_string(const basic_string& other);
basic_string(basic_string&& other);

// Idea being if we are constructing a new string from a temporary object (which
// is going to be destroyed soon anyway), we can have a more efficient
// constructor that "salvages" parts of that temporary string. You will see this
// concept referred to as "move semantics".
// Out:
// input_line_24:11:6: error: invalid operands to binary expression ('std::ostream' (aka 'basic_ostream<char>') and 'std::string *' (aka 'basic_string<char> *'))
// cout << &fooRef << endl; //Prints the address of foo
// ~~~~ ^  ~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/cstddef:125:5: note: candidate function template not viable: no known conversion from 'std::ostream' (aka 'basic_ostream<char>') to 'std::byte' for 1st argument
//     operator<<(byte __b, _IntegerType __shift) noexcept
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/system_error:262:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'const std::error_code' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const error_code& __e)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:117:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'std::basic_ostream<char, std::char_traits<char> >::__ios_type &(*)(std::basic_ostream<char, std::char_traits<char> >::__ios_type &)' (aka 'basic_ios<char, std::char_traits<char> > &(*)(basic_ios<char, std::char_traits<char> > &)') for 1st argument
//       operator<<(__ios_type& (*__pf)(__ios_type&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:127:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'std::ios_base &(*)(std::ios_base &)' for 1st argument
//       operator<<(ios_base& (*__pf) (ios_base&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:166:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'long' for 1st argument
//       operator<<(long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:170:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'unsigned long' for 1st argument
//       operator<<(unsigned long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:178:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'short' for 1st argument
//       operator<<(short __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:181:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'unsigned short' for 1st argument
//       operator<<(unsigned short __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:189:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'int' for 1st argument
//       operator<<(int __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:192:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'unsigned int' for 1st argument
//       operator<<(unsigned int __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:201:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'long long' for 1st argument
//       operator<<(long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:205:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'unsigned long long' for 1st argument
//       operator<<(unsigned long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:220:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'double' for 1st argument
//       operator<<(double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:224:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'float' for 1st argument
//       operator<<(float __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:232:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'long double' for 1st argument
//       operator<<(long double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:250:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'std::nullptr_t' (aka 'nullptr_t') for 1st argument
//       operator<<(nullptr_t)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:276:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'std::basic_ostream<char, std::char_traits<char> >::__streambuf_type *' (aka 'basic_streambuf<char, std::char_traits<char> > *') for 1st argument
//       operator<<(__streambuf_type* __sb);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:511:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:517:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:523:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'signed char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, signed char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:528:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'unsigned char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, unsigned char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:606:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'const char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:619:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'const signed char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const signed char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:624:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'const unsigned char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const unsigned char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/ostream.tcc:321:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:506:5: note: candidate template ignored: deduced conflicting types for parameter '_CharT' ('char' vs. 'std::__cxx11::basic_string<char> *')
//     operator<<(basic_ostream<_CharT, _Traits>& __out, _CharT __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:589:5: note: candidate template ignored: deduced conflicting types for parameter '_CharT' ('char' vs. 'std::__cxx11::basic_string<char>')
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const _CharT* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/string_view:621:5: note: candidate template ignored: could not match 'basic_string_view<type-parameter-0-0, type-parameter-0-1>' against 'std::__cxx11::basic_string<char> *'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:6480:5: note: candidate template ignored: could not match 'basic_string<type-parameter-0-0, type-parameter-0-1, type-parameter-0-2>' against 'std::__cxx11::basic_string<char> *'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/shared_ptr.h:69:5: note: candidate template ignored: could not match '__shared_ptr<type-parameter-0-2, _Lp>' against 'std::__cxx11::basic_string<char> *'
//     operator<<(std::basic_ostream<_Ch, _Tr>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:344:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom1, typename _Dom1::value_type>& __v,   \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:357:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom, typename _Dom::value_type>& __v,     \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr<type-parameter-0-0, typename type-parameter-0-0::value_type>' against 'std::__cxx11::basic_string<char> *'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:370:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const typename _Dom::value_type& __t,                  \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:383:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom,typename _Dom::value_type>& __e,      \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr<type-parameter-0-0, typename type-parameter-0-0::value_type>' against 'std::__cxx11::basic_string<char> *'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:396:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const valarray<typename _Dom::value_type>& __v,        \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1155:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v, const valarray<_Tp>& __w)    \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1166:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v,                              \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray<type-parameter-0-0>' against 'std::__cxx11::basic_string<char> *'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1177:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const typename valarray<_Tp>::value_type& __t,         \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:773:5: note: candidate template ignored: substitution failure [with _Ostream = std::basic_ostream<char> &, _Tp = std::__cxx11::basic_string<char> *]: no member named 'value' in 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >, std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, std::__cxx11::basic_string<char> *const &, void> >'
//     operator<<(_Ostream&& __os, const _Tp& __x)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/complex:554:5: note: candidate template ignored: could not match 'complex<type-parameter-0-0>' against 'std::__cxx11::basic_string<char> *'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const complex<_Tp>& __x)
//     ^
// input_line_24:13:6: error: invalid operands to binary expression ('std::ostream' (aka 'basic_ostream<char>') and 'std::string *' (aka 'basic_string<char> *'))
// cout << &fooRef << endl; //Still prints the address of foo
// ~~~~ ^  ~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/cstddef:125:5: note: candidate function template not viable: no known conversion from 'std::ostream' (aka 'basic_ostream<char>') to 'std::byte' for 1st argument
//     operator<<(byte __b, _IntegerType __shift) noexcept
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/system_error:262:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'const std::error_code' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const error_code& __e)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:117:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'std::basic_ostream<char, std::char_traits<char> >::__ios_type &(*)(std::basic_ostream<char, std::char_traits<char> >::__ios_type &)' (aka 'basic_ios<char, std::char_traits<char> > &(*)(basic_ios<char, std::char_traits<char> > &)') for 1st argument
//       operator<<(__ios_type& (*__pf)(__ios_type&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:127:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'std::ios_base &(*)(std::ios_base &)' for 1st argument
//       operator<<(ios_base& (*__pf) (ios_base&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:166:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'long' for 1st argument
//       operator<<(long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:170:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'unsigned long' for 1st argument
//       operator<<(unsigned long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:178:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'short' for 1st argument
//       operator<<(short __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:181:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'unsigned short' for 1st argument
//       operator<<(unsigned short __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:189:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'int' for 1st argument
//       operator<<(int __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:192:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'unsigned int' for 1st argument
//       operator<<(unsigned int __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:201:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'long long' for 1st argument
//       operator<<(long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:205:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'unsigned long long' for 1st argument
//       operator<<(unsigned long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:220:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'double' for 1st argument
//       operator<<(double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:224:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'float' for 1st argument
//       operator<<(float __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:232:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'long double' for 1st argument
//       operator<<(long double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:250:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'std::nullptr_t' (aka 'nullptr_t') for 1st argument
//       operator<<(nullptr_t)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:276:7: note: candidate function not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'std::basic_ostream<char, std::char_traits<char> >::__streambuf_type *' (aka 'basic_streambuf<char, std::char_traits<char> > *') for 1st argument
//       operator<<(__streambuf_type* __sb);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:511:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:517:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:523:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'signed char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, signed char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:528:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'unsigned char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, unsigned char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:606:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'const char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:619:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'const signed char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const signed char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:624:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'const unsigned char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const unsigned char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/ostream.tcc:321:5: note: candidate function template not viable: no known conversion from 'std::string *' (aka 'basic_string<char> *') to 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:506:5: note: candidate template ignored: deduced conflicting types for parameter '_CharT' ('char' vs. 'std::__cxx11::basic_string<char> *')
//     operator<<(basic_ostream<_CharT, _Traits>& __out, _CharT __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:589:5: note: candidate template ignored: deduced conflicting types for parameter '_CharT' ('char' vs. 'std::__cxx11::basic_string<char>')
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const _CharT* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/string_view:621:5: note: candidate template ignored: could not match 'basic_string_view<type-parameter-0-0, type-parameter-0-1>' against 'std::__cxx11::basic_string<char> *'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:6480:5: note: candidate template ignored: could not match 'basic_string<type-parameter-0-0, type-parameter-0-1, type-parameter-0-2>' against 'std::__cxx11::basic_string<char> *'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/shared_ptr.h:69:5: note: candidate template ignored: could not match '__shared_ptr<type-parameter-0-2, _Lp>' against 'std::__cxx11::basic_string<char> *'
//     operator<<(std::basic_ostream<_Ch, _Tr>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:344:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom1, typename _Dom1::value_type>& __v,   \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:357:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom, typename _Dom::value_type>& __v,     \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr<type-parameter-0-0, typename type-parameter-0-0::value_type>' against 'std::__cxx11::basic_string<char> *'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:370:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const typename _Dom::value_type& __t,                  \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:383:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom,typename _Dom::value_type>& __e,      \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr<type-parameter-0-0, typename type-parameter-0-0::value_type>' against 'std::__cxx11::basic_string<char> *'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:396:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const valarray<typename _Dom::value_type>& __v,        \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1155:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v, const valarray<_Tp>& __w)    \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1166:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v,                              \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray<type-parameter-0-0>' against 'std::__cxx11::basic_string<char> *'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1177:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const typename valarray<_Tp>::value_type& __t,         \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:773:5: note: candidate template ignored: substitution failure [with _Ostream = std::basic_ostream<char> &, _Tp = std::__cxx11::basic_string<char> *]: no member named 'value' in 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >, std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, std::__cxx11::basic_string<char> *const &, void> >'
//     operator<<(_Ostream&& __os, const _Tp& __x)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/complex:554:5: note: candidate template ignored: could not match 'complex<type-parameter-0-0>' against 'std::__cxx11::basic_string<char> *'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const complex<_Tp>& __x)
//     ^
// input_line_24:18:8: error: no viable overloaded '+='
// barRef += ". Hi!"; // Error, const references cannot be modified.
// ~~~~~~ ^  ~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:1152:7: note: candidate function not viable: 'this' argument has type 'const std::string' (aka 'const basic_string<char>'), but method is not marked const
//       operator+=(const basic_string& __str)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:1195:2: note: candidate function template not viable: 'this' argument has type 'const std::string' (aka 'const basic_string<char>'), but method is not marked const
//         operator+=(const _Tp& __svt)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:1161:7: note: candidate function not viable: 'this' argument has type 'const std::string' (aka 'const basic_string<char>'), but method is not marked const
//       operator+=(const _CharT* __s)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:1170:7: note: candidate function not viable: 'this' argument has type 'const std::string' (aka 'const basic_string<char>'), but method is not marked const
//       operator+=(_CharT __c)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:1183:7: note: candidate function not viable: 'this' argument has type 'const std::string' (aka 'const basic_string<char>'), but method is not marked const
//       operator+=(initializer_list<_CharT> __l)
//       ^
// input_line_24:21:24: error: function definition is not allowed here
// string tempObjectFun() { ... }
//                        ^
// input_line_24:22:17: error: use of undeclared identifier 'tempObjectFun'
// string retVal = tempObjectFun();
//                 ^
// input_line_24:34:9: error: use of undeclared identifier 'tempObjectFun'
// foo(bar(tempObjectFun()))
//         ^
// input_line_24:52:1: error: use of undeclared identifier 'someFun'
// someFun(foo);  // Calls the version with regular reference
// ^
// input_line_24:53:9: error: use of undeclared identifier 'tempObjectFun'
// someFun(tempObjectFun());  // Calls the version with temporary reference
//         ^
// input_line_24:56:14: error: expected expression
// basic_string(const basic_string& other);
//              ^
// input_line_24:57:14: error: use of class template 'basic_string' requires template arguments
// basic_string(basic_string&& other);
//              ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:85:11: note: template is declared here
//     class basic_string
//           ^
// input_line_24:57:29: error: use of undeclared identifier 'other'
// basic_string(basic_string&& other);
//                             ^
// Interpreter Error:

// %% [markdown]
// Enums
// ---

// %%
// Enums are a way to assign a value to a constant most commonly used for
// easier visualization and reading of code
enum ECarTypes
{
  Sedan,
  Hatchback,
  SUV,
  Wagon
};

// %%
ECarTypes GetPreferredCarType()
{
    return ECarTypes::Hatchback;
}

// %% [markdown]
// As of C++11 there is an easy way to assign a type to the enum which can be useful in serialization of data and converting enums back-and-forth between the desired type and their respective constants:

// %%
enum ECarTypes : uint8_t
{
  Sedan, // 0
  Hatchback, // 1
  SUV = 254, // 254
  Hybrid // 255
};

// %%
void WriteByteToFile(uint8_t InputValue)
{
    // Serialize the InputValue to a file
}

// %%
void WritePreferredCarTypeToFile(ECarTypes InputCarType)
{
    // The enum is implicitly converted to a uint8_t due to its declared enum type
    WriteByteToFile(InputCarType);
}

// %% [markdown]
// On the other hand you may not want enums to be accidentally cast to an integer type or to other enums so it is instead possible to create an enum class which won't be implicitly converted:

// %%
enum class ECarTypes : uint8_t
{
  Sedan, // 0
  Hatchback, // 1
  SUV = 254, // 254
  Hybrid // 255
};

// %%
void WriteByteToFile(uint8_t InputValue)
{
    // Serialize the InputValue to a file
}

// %%
void WritePreferredCarTypeToFile(ECarTypes InputCarType)
{
    // Won't compile even though ECarTypes is a uint8_t due to the enum
    // being declared as an "enum class"!
    WriteByteToFile(InputCarType);
}
// Out:
// input_line_37:5:5: error: no matching function for call to 'WriteByteToFile'
//     WriteByteToFile(InputCarType);
//     ^~~~~~~~~~~~~~~
// input_line_36:1:6: note: candidate function not viable: no known conversion from 'ECarTypes' to 'uint8_t' (aka 'unsigned char') for 1st argument
// void WriteByteToFile(uint8_t InputValue)
//      ^
// Interpreter Error:

// %% [markdown]
// Classes and object-oriented programming
// ---

// %%
// First example of classes
#include <iostream>

// Declare a class.
// Classes are usually declared in header (.h or .hpp) files.
class Dog {
    // Member variables and functions are private by default.
    std::string name;
    int weight;

// All members following this are public
// until "private:" or "protected:" is found.
public:

    // Default constructor
    Dog();

    // Member function declarations (implementations to follow)
    // Note that we use std::string here instead of placing
    // using namespace std;
    // above.
    // Never put a "using namespace" statement in a header.
    void setName(const std::string& dogsName);

    void setWeight(int dogsWeight);

    // Functions that do not modify the state of the object
    // should be marked as const.
    // This allows you to call them if given a const reference to the object.
    // Also note the functions must be explicitly declared as _virtual_
    // in order to be overridden in derived classes.
    // Functions are not virtual by default for performance reasons.
    virtual void print() const;

    // Functions can also be defined inside the class body.
    // Functions defined as such are automatically inlined.
    void bark() const { std::cout << name << " barks!\n"; }

    // Along with constructors, C++ provides destructors.
    // These are called when an object is deleted or falls out of scope.
    // This enables powerful paradigms such as RAII
    // (see below)
    // The destructor should be virtual if a class is to be derived from;
    // if it is not virtual, then the derived class' destructor will
    // not be called if the object is destroyed through a base-class reference
    // or pointer.
    virtual ~Dog();

}; // A semicolon must follow the class definition.

// Class member functions are usually implemented in .cpp files.
Dog::Dog()
{
    std::cout << "A dog has been constructed\n";
}

// Objects (such as strings) should be passed by reference
// if you are modifying them or const reference if you are not.
void Dog::setName(const std::string& dogsName)
{
    name = dogsName;
}

void Dog::setWeight(int dogsWeight)
{
    weight = dogsWeight;
}

// Notice that "virtual" is only needed in the declaration, not the definition.
void Dog::print() const
{
    std::cout << "Dog is " << name << " and weighs " << weight << "kg\n";
}

Dog::~Dog()
{
    std::cout << "Goodbye " << name << '\n';
}

int main() {
    Dog myDog; // prints "A dog has been constructed"
    myDog.setName("Barkley");
    myDog.setWeight(10);
    myDog.print(); // prints "Dog is Barkley and weighs 10 kg"
    return 0;
} // prints "Goodbye Barkley"

// Inheritance:

// This class inherits everything public and protected from the Dog class
// as well as private but may not directly access private members/methods
// without a public or protected method for doing so
class OwnedDog : public Dog {

public:
    void setOwner(const std::string& dogsOwner);

    // Override the behavior of the print function for all OwnedDogs. See
    // https://en.wikipedia.org/wiki/Polymorphism_(computer_science)#Subtyping
    // for a more general introduction if you are unfamiliar with
    // subtype polymorphism.
    // The override keyword is optional but makes sure you are actually
    // overriding the method in a base class.
    void print() const override;

private:
    std::string owner;
};

// Meanwhile, in the corresponding .cpp file:

void OwnedDog::setOwner(const std::string& dogsOwner)
{
    owner = dogsOwner;
}

void OwnedDog::print() const
{
    Dog::print(); // Call the print function in the base Dog class
    std::cout << "Dog is owned by " << owner << '\n';
    // Prints "Dog is <name> and weights <weight>"
    //        "Dog is owned by <owner>"
}
// Out:
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:767:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >, std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, char const (&)[9], void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// input_line_40:28:43: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = char [9]]
//     void bark() const { std::cout << name << " barks!\n"; }
//                                           ^
// input_line_40:41:7: error: qualified reference to 'Dog' is a constructor name rather than a type in this context
//  Dog::Dog()
//       ^
// input_line_40:41:12: error: expected ';' after expression
//  Dog::Dog()
//            ^
//            ;
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:767:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >, std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, char const (&)[28], void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// input_line_40:43:15: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = char [28]]
//     std::cout << "A dog has been constructed\n";
//               ^
// input_line_40:48:1: error: function definition is not allowed here
// {
// ^
// input_line_40:52:1: error: function definition is not allowed here
// {
// ^
// input_line_40:57:1: error: function definition is not allowed here
// {
// ^
// input_line_40:60:6: error: call to non-static member function without an object argument
// Dog::~Dog()
// ~~~~~^
// input_line_40:89:6: error: use of undeclared identifier 'OwnedDog'
// void OwnedDog::setOwner(const std::string& dogsOwner)
//      ^
// input_line_40:93:6: error: use of undeclared identifier 'OwnedDog'
// void OwnedDog::print() const
//      ^
// Interpreter Error:

// %% [markdown]
// Initialization and Operator Overloading
// ---
// In C++ you can overload the behavior of operators such as +, -, *, /, etc.
//
// This is done by defining a function which is called whenever the operator is used.

// %%
#include <iostream>
using namespace std;

class Point {
public:
    // Member variables can be given default values in this manner.
    double x = 0;
    double y = 0;

    // Define a default constructor which does nothing
    // but initialize the Point to the default value (0, 0)
    Point() { };

    // The following syntax is known as an initialization list
    // and is the proper way to initialize class member values
    Point (double a, double b) :
        x(a),
        y(b)
    { /* Do nothing except initialize the values */ }

    // Overload the + operator.
    Point operator+(const Point& rhs) const;

    // Overload the += operator
    Point& operator+=(const Point& rhs);

    // It would also make sense to add the - and -= operators,
    // but we will skip those for brevity.
};

// %%
Point Point::operator+(const Point& rhs) const
{
    // Create a new point that is the sum of this one and rhs.
    return Point(x + rhs.x, y + rhs.y);
}
// Out:
// input_line_44:3:1: error: function definition is not allowed here
// {
// ^
// Interpreter Error:

// %%
// It's good practice to return a reference to the leftmost variable of
// an assignment. `(a += b) == c` will work this way.
Point& Point::operator+=(const Point& rhs)
{
    x += rhs.x;
    y += rhs.y;

    // `this` is a pointer to the object, on which a method is called.
    return *this;
}
// Out:
// input_line_45:5:1: error: function definition is not allowed here
// {
// ^
// Interpreter Error:

// %%
int main () {
    Point up (0,1);
    Point right (1,0);
    // This calls the Point + operator
    // Point up calls the + (function) with right as its parameter
    Point result = up + right;
    // Prints "Result is upright (1,1)"
    cout << "Result is upright (" << result.x << ',' << result.y << ")\n";
    return 0;
}
// Out:
// input_line_48:8:35: error: use of overloaded operator '<<' is ambiguous (with operand types 'basic_ostream<char, std::char_traits<char> >' and 'double')
//     cout << "Result is upright (" << result.x << ',' << result.y << ")\n";
//     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~ ^  ~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:166:7: note: candidate function
//       operator<<(long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:170:7: note: candidate function
//       operator<<(unsigned long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:178:7: note: candidate function
//       operator<<(short __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:181:7: note: candidate function
//       operator<<(unsigned short __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:189:7: note: candidate function
//       operator<<(int __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:192:7: note: candidate function
//       operator<<(unsigned int __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:201:7: note: candidate function
//       operator<<(long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:205:7: note: candidate function
//       operator<<(unsigned long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:224:7: note: candidate function
//       operator<<(float __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:232:7: note: candidate function
//       operator<<(long double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:517:5: note: candidate function [with _Traits = std::char_traits<char>]
//     operator<<(basic_ostream<char, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:511:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>]
//     operator<<(basic_ostream<_CharT, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:523:5: note: candidate function [with _Traits = std::char_traits<char>]
//     operator<<(basic_ostream<char, _Traits>& __out, signed char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:528:5: note: candidate function [with _Traits = std::char_traits<char>]
//     operator<<(basic_ostream<char, _Traits>& __out, unsigned char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:609:8: error: no member named 'setstate' in 'std::basic_ostream<char>'
//         __out.setstate(ios_base::badbit);
//         ~~~~~ ^
// input_line_48:8:10: note: in instantiation of function template specialization 'std::operator<<<std::char_traits<char> >' requested here
//     cout << "Result is upright (" << result.x << ',' << result.y << ")\n";
//          ^
// Interpreter Error:

// %% [markdown]
// Templates
// ---
// Templates in C++ are mostly used for generic programming, though they are much more powerful than generic constructs in other languages. They also support explicit and partial specialization and functional-style type classes; in fact, they are a Turing-complete functional language embedded in C++!
//
// We start with the kind of generic programming you might be familiar with. To define a class or function that takes a type parameter:

// %%
template<class T>
class Box {
public:
    // In this class, T can be used as any other type.
    void insert(const T&) { ... }
};

// During compilation, the compiler actually generates copies of each template
// with parameters substituted, so the full definition of the class must be
// present at each invocation. This is why you will see template classes defined
// entirely in header files.

// To instantiate a template class on the stack:
Box<int> intBox;

// and you can use it as you would expect:
intBox.insert(123);

// You can, of course, nest templates:
Box<Box<int> > boxOfBox;
boxOfBox.insert(intBox);

// Until C++11, you had to place a space between the two '>'s, otherwise '>>'
// would be parsed as the right shift operator.

// You will sometimes see
//   template<typename T>
// instead. The 'class' keyword and 'typename' keywords are _mostly_
// interchangeable in this case. For the full explanation, see
//   https://en.wikipedia.org/wiki/Typename
// (yes, that keyword has its own Wikipedia page).

// Similarly, a template function:
template<class T>
void barkThreeTimes(const T& input)
{
    input.bark();
    input.bark();
    input.bark();
}

// Notice that nothing is specified about the type parameters here. The compiler
// will generate and then type-check every invocation of the template, so the
// above function works with any type 'T' that has a const 'bark' method!

Dog fluffy;
fluffy.setName("Fluffy")
barkThreeTimes(fluffy); // Prints "Fluffy barks" three times.

// Template parameters don't have to be classes:
template<int Y>
void printMessage() {
  cout << "Learn C++ in " << Y << " minutes!" << endl;
}

// And you can explicitly specialize templates for more efficient code. Of
// course, most real-world uses of specialization are not as trivial as this.
// Note that you still need to declare the function (or class) as a template
// even if you explicitly specified all parameters.
template<>
void printMessage<10>() {
  cout << "Learn C++ faster in only 10 minutes!" << endl;
}

printMessage<20>();  // Prints "Learn C++ in 20 minutes!"
printMessage<10>();  // Prints "Learn C++ faster in only 10 minutes!"
// Out:
// input_line_47:5:29: error: expected expression
//     void insert(const T&) { ... }
//                             ^
// input_line_47:14:1: error: unknown type name 'intBox'
// intBox.insert(123);
// ^
// input_line_47:14:7: error: cannot use dot operator on a type
// intBox.insert(123);
//       ^
// input_line_47:17:1: error: unknown type name 'boxOfBox'
// boxOfBox.insert(intBox);
// ^
// input_line_47:17:9: error: cannot use dot operator on a type
// boxOfBox.insert(intBox);
//         ^
// input_line_47:37:1: error: unknown type name 'Dog'
// Dog fluffy;
// ^
// input_line_47:38:1: error: unknown type name 'fluffy'
// fluffy.setName("Fluffy")
// ^
// input_line_47:38:7: error: cannot use dot operator on a type
// fluffy.setName("Fluffy")
//       ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:767:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >, std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, char const (&)[14], void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// input_line_47:43:8: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = char [14]]
//   cout << "Learn C++ in " << Y << " minutes!" << endl;
//        ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:767:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >, std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, const int &, void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// input_line_47:43:27: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = int]
//   cout << "Learn C++ in " << Y << " minutes!" << endl;
//                           ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:767:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >, std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, char const (&)[10], void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// input_line_47:43:32: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = char [10]]
//   cout << "Learn C++ in " << Y << " minutes!" << endl;
//                                ^
// input_line_47:43:50: error: reference to overloaded function could not be resolved; did you mean to call it?
//   cout << "Learn C++ in " << Y << " minutes!" << endl;
//                                                  ^~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:681:5: note: possible target for call
//     endl(basic_ostream<_CharT, _Traits>& __os)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/string_view:621:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'basic_string_view<char, std::char_traits<char> >' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/system_error:262:5: note: candidate function template not viable: no overload of 'endl' matching 'const std::error_code' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const error_code& __e)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:117:7: note: candidate function not viable: no overload of 'endl' matching 'std::basic_ostream<char, std::char_traits<char> >::__ios_type &(*)(std::basic_ostream<char, std::char_traits<char> >::__ios_type &)' (aka 'basic_ios<char, std::char_traits<char> > &(*)(basic_ios<char, std::char_traits<char> > &)') for 1st argument
//       operator<<(__ios_type& (*__pf)(__ios_type&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:127:7: note: candidate function not viable: no overload of 'endl' matching 'std::ios_base &(*)(std::ios_base &)' for 1st argument
//       operator<<(ios_base& (*__pf) (ios_base&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:166:7: note: candidate function not viable: no overload of 'endl' matching 'long' for 1st argument
//       operator<<(long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:170:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned long' for 1st argument
//       operator<<(unsigned long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:178:7: note: candidate function not viable: no overload of 'endl' matching 'short' for 1st argument
//       operator<<(short __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:181:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned short' for 1st argument
//       operator<<(unsigned short __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:189:7: note: candidate function not viable: no overload of 'endl' matching 'int' for 1st argument
//       operator<<(int __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:192:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned int' for 1st argument
//       operator<<(unsigned int __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:201:7: note: candidate function not viable: no overload of 'endl' matching 'long long' for 1st argument
//       operator<<(long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:205:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned long long' for 1st argument
//       operator<<(unsigned long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:224:7: note: candidate function not viable: no overload of 'endl' matching 'float' for 1st argument
//       operator<<(float __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:232:7: note: candidate function not viable: no overload of 'endl' matching 'long double' for 1st argument
//       operator<<(long double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:250:7: note: candidate function not viable: no overload of 'endl' matching 'std::nullptr_t' (aka 'nullptr_t') for 1st argument
//       operator<<(nullptr_t)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:276:7: note: candidate function not viable: no overload of 'endl' matching 'std::basic_ostream<char, std::char_traits<char> >::__streambuf_type *' (aka 'basic_streambuf<char, std::char_traits<char> > *') for 1st argument
//       operator<<(__streambuf_type* __sb);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:506:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, _CharT __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:511:5: note: candidate function template not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:517:5: note: candidate function template not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:523:5: note: candidate function template not viable: no overload of 'endl' matching 'signed char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, signed char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:528:5: note: candidate function template not viable: no overload of 'endl' matching 'unsigned char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, unsigned char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:589:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const _CharT* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:606:5: note: candidate function template not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:619:5: note: candidate function template not viable: no overload of 'endl' matching 'const signed char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const signed char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:624:5: note: candidate function template not viable: no overload of 'endl' matching 'const unsigned char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const unsigned char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/ostream.tcc:321:5: note: candidate function template not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:6480:5: note: candidate template ignored: couldn't infer template argument '_Alloc'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/cstddef:125:5: note: candidate template ignored: couldn't infer template argument '_IntegerType'
//     operator<<(byte __b, _IntegerType __shift) noexcept
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/shared_ptr.h:69:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(std::basic_ostream<_Ch, _Tr>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: couldn't infer template argument '_Dom'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:370:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const typename _Dom::value_type& __t,                  \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: couldn't infer template argument '_Dom'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:396:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const valarray<typename _Dom::value_type>& __v,        \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: couldn't infer template argument '_Tp'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1177:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const typename valarray<_Tp>::value_type& __t,         \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:773:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(_Ostream&& __os, const _Tp& __x)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/complex:554:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const complex<_Tp>& __x)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:344:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom1, typename _Dom1::value_type>& __v,   \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:357:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom, typename _Dom::value_type>& __v,     \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:383:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom,typename _Dom::value_type>& __e,      \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1155:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v, const valarray<_Tp>& __w)    \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1166:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v,                              \
//     ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:767:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >, std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, char const (&)[37], void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// input_line_47:51:8: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = char [37]]
//   cout << "Learn C++ faster in only 10 minutes!" << endl;
//        ^
// input_line_47:51:53: error: reference to overloaded function could not be resolved; did you mean to call it?
//   cout << "Learn C++ faster in only 10 minutes!" << endl;
//                                                     ^~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:681:5: note: possible target for call
//     endl(basic_ostream<_CharT, _Traits>& __os)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/string_view:621:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'basic_string_view<char, std::char_traits<char> >' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/system_error:262:5: note: candidate function template not viable: no overload of 'endl' matching 'const std::error_code' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const error_code& __e)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:117:7: note: candidate function not viable: no overload of 'endl' matching 'std::basic_ostream<char, std::char_traits<char> >::__ios_type &(*)(std::basic_ostream<char, std::char_traits<char> >::__ios_type &)' (aka 'basic_ios<char, std::char_traits<char> > &(*)(basic_ios<char, std::char_traits<char> > &)') for 1st argument
//       operator<<(__ios_type& (*__pf)(__ios_type&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:127:7: note: candidate function not viable: no overload of 'endl' matching 'std::ios_base &(*)(std::ios_base &)' for 1st argument
//       operator<<(ios_base& (*__pf) (ios_base&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:166:7: note: candidate function not viable: no overload of 'endl' matching 'long' for 1st argument
//       operator<<(long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:170:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned long' for 1st argument
//       operator<<(unsigned long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:178:7: note: candidate function not viable: no overload of 'endl' matching 'short' for 1st argument
//       operator<<(short __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:181:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned short' for 1st argument
//       operator<<(unsigned short __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:189:7: note: candidate function not viable: no overload of 'endl' matching 'int' for 1st argument
//       operator<<(int __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:192:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned int' for 1st argument
//       operator<<(unsigned int __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:201:7: note: candidate function not viable: no overload of 'endl' matching 'long long' for 1st argument
//       operator<<(long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:205:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned long long' for 1st argument
//       operator<<(unsigned long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:224:7: note: candidate function not viable: no overload of 'endl' matching 'float' for 1st argument
//       operator<<(float __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:232:7: note: candidate function not viable: no overload of 'endl' matching 'long double' for 1st argument
//       operator<<(long double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:250:7: note: candidate function not viable: no overload of 'endl' matching 'std::nullptr_t' (aka 'nullptr_t') for 1st argument
//       operator<<(nullptr_t)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:276:7: note: candidate function not viable: no overload of 'endl' matching 'std::basic_ostream<char, std::char_traits<char> >::__streambuf_type *' (aka 'basic_streambuf<char, std::char_traits<char> > *') for 1st argument
//       operator<<(__streambuf_type* __sb);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:506:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, _CharT __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:511:5: note: candidate function template not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:517:5: note: candidate function template not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:523:5: note: candidate function template not viable: no overload of 'endl' matching 'signed char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, signed char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:528:5: note: candidate function template not viable: no overload of 'endl' matching 'unsigned char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, unsigned char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:589:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const _CharT* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:606:5: note: candidate function template not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:619:5: note: candidate function template not viable: no overload of 'endl' matching 'const signed char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const signed char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:624:5: note: candidate function template not viable: no overload of 'endl' matching 'const unsigned char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const unsigned char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/ostream.tcc:321:5: note: candidate function template not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:6480:5: note: candidate template ignored: couldn't infer template argument '_Alloc'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/cstddef:125:5: note: candidate template ignored: couldn't infer template argument '_IntegerType'
//     operator<<(byte __b, _IntegerType __shift) noexcept
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/shared_ptr.h:69:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(std::basic_ostream<_Ch, _Tr>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: couldn't infer template argument '_Dom'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:370:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const typename _Dom::value_type& __t,                  \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: couldn't infer template argument '_Dom'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:396:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const valarray<typename _Dom::value_type>& __v,        \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: couldn't infer template argument '_Tp'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1177:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const typename valarray<_Tp>::value_type& __t,         \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:773:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(_Ostream&& __os, const _Tp& __x)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/complex:554:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const complex<_Tp>& __x)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:344:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom1, typename _Dom1::value_type>& __v,   \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:357:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom, typename _Dom::value_type>& __v,     \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:383:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom,typename _Dom::value_type>& __e,      \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1155:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v, const valarray<_Tp>& __w)    \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1166:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v,                              \
//     ^
// input_line_47:53:1: error: C++ requires a type specifier for all declarations
// printMessage<20>();  // Prints "Learn C++ in 20 minutes!"
// ^
// input_line_47:53:1: error: template specialization requires 'template<>'
// printMessage<20>();  // Prints "Learn C++ in 20 minutes!"
// ^           ~~~~
// template<>
// input_line_47:54:1: error: C++ requires a type specifier for all declarations
// printMessage<10>();  // Prints "Learn C++ faster in only 10 minutes!"
// ^
// input_line_47:54:1: error: template specialization requires 'template<>'
// printMessage<10>();  // Prints "Learn C++ faster in only 10 minutes!"
// ^           ~~~~
// template<>
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:17:
// In file included from /srv/conda/envs/notebook/include/xeus/xcomm.hpp:19:
// In file included from /srv/conda/envs/notebook/include/nlohmann/json.hpp:55:
// In file included from /srv/conda/envs/notebook/include/nlohmann/detail/input/binary_reader.hpp:16:
// In file included from /srv/conda/envs/notebook/include/nlohmann/detail/input/input_adapters.hpp:7:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/istream:39:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:609:8: error: no member named 'setstate' in 'std::basic_ostream<char>'
//         __out.setstate(ios_base::badbit);
//         ~~~~~ ^
// input_line_47:51:8: note: in instantiation of function template specialization 'std::operator<<<std::char_traits<char> >' requested here
//   cout << "Learn C++ faster in only 10 minutes!" << endl;
//        ^
// Interpreter Error:

// %%
/////////////////////
// Exception Handling
/////////////////////

// The standard library provides a few exception types
// (see https://en.cppreference.com/w/cpp/error/exception)
// but any type can be thrown as an exception
#include <exception>
#include <stdexcept>

// All exceptions thrown inside the _try_ block can be caught by subsequent
// _catch_ handlers.
try {
    // Do not allocate exceptions on the heap using _new_.
    throw std::runtime_error("A problem occurred");
}

// Catch exceptions by const reference if they are objects
catch (const std::exception& ex)
{
    std::cout << ex.what();
}

// Catches any exception not caught by previous _catch_ blocks
catch (...)
{
    std::cout << "Unknown exception caught";
    throw; // Re-throws the exception
}
// Out:
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:767:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >, std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, const char *const &, void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// input_line_70:11:15: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = const char *]
//     std::cout << ex.what();
//               ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:767:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_ostream<char> &> >, std::__is_convertible_to_basic_ostream<std::basic_ostream<char> &>, std::__is_insertable<std::basic_ostream<char> &, char const (&)[25], void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Ostream>>,
//                        ^
// input_line_70:16:15: note: while substituting deduced template arguments into function template 'operator<<' [with _Ostream = std::basic_ostream<char> &, _Tp = char [25]]
//     std::cout << "Unknown exception caught";
//               ^
// Interpreter Error:

// %% [markdown]
// RAII
// ---

// %%
// RAII stands for "Resource Acquisition Is Initialization".
// It is often considered the most powerful paradigm in C++
// and is the simple concept that a constructor for an object
// acquires that object's resources and the destructor releases them.

// To understand how this is useful,
// consider a function that uses a C file handle:
void doSomethingWithAFile(const char* filename)
{
    // To begin with, assume nothing can fail.

    FILE* fh = fopen(filename, "r"); // Open the file in read mode.

    doSomethingWithTheFile(fh);
    doSomethingElseWithIt(fh);

    fclose(fh); // Close the file handle.
}

// Unfortunately, things are quickly complicated by error handling.
// Suppose fopen can fail, and that doSomethingWithTheFile and
// doSomethingElseWithIt return error codes if they fail.
//  (Exceptions are the preferred way of handling failure,
//   but some programmers, especially those with a C background,
//   disagree on the utility of exceptions).
// We now have to check each call for failure and close the file handle
// if a problem occurred.
bool doSomethingWithAFile(const char* filename)
{
    FILE* fh = fopen(filename, "r"); // Open the file in read mode
    if (fh == nullptr) // The returned pointer is null on failure.
        return false; // Report that failure to the caller.

    // Assume each function returns false if it failed
    if (!doSomethingWithTheFile(fh)) {
        fclose(fh); // Close the file handle so it doesn't leak.
        return false; // Propagate the error.
    }
    if (!doSomethingElseWithIt(fh)) {
        fclose(fh); // Close the file handle so it doesn't leak.
        return false; // Propagate the error.
    }

    fclose(fh); // Close the file handle so it doesn't leak.
    return true; // Indicate success
}

// C programmers often clean this up a little bit using goto:
bool doSomethingWithAFile(const char* filename)
{
    FILE* fh = fopen(filename, "r");
    if (fh == nullptr)
        return false;

    if (!doSomethingWithTheFile(fh))
        goto failure;

    if (!doSomethingElseWithIt(fh))
        goto failure;

    fclose(fh); // Close the file
    return true; // Indicate success

failure:
    fclose(fh);
    return false; // Propagate the error
}

// If the functions indicate errors using exceptions,
// things are a little cleaner, but still sub-optimal.
void doSomethingWithAFile(const char* filename)
{
    FILE* fh = fopen(filename, "r"); // Open the file in shared_ptrread mode
    if (fh == nullptr)
        throw std::runtime_error("Could not open the file.");

    try {
        doSomethingWithTheFile(fh);
        doSomethingElseWithIt(fh);
    }
    catch (...) {
        fclose(fh); // Be sure to close the file if an error occurs.
        throw; // Then re-throw the exception.
    }

    fclose(fh); // Close the file
    // Everything succeeded
}

// Compare this to the use of C++'s file stream class (fstream)
// fstream uses its destructor to close the file.
// Recall from above that destructors are automatically called
// whenever an object falls out of scope.
void doSomethingWithAFile(const std::string& filename)
{
    // ifstream is short for input file stream
    std::ifstream fh(filename); // Open the file

    // Do things with the file
    doSomethingWithTheFile(fh);
    doSomethingElseWithIt(fh);

} // The file is automatically closed here by the destructor

// This has _massive_ advantages:
// 1. No matter what happens,
//    the resource (in this case the file handle) will be cleaned up.
//    Once you write the destructor correctly,
//    It is _impossible_ to forget to close the handle and leak the resource.
// 2. Note that the code is much cleaner.
//    The destructor handles closing the file behind the scenes
//    without you having to worry about it.
// 3. The code is exception safe.
//    An exception can be thrown anywhere in the function and cleanup
//    will still occur.

// All idiomatic C++ code uses RAII extensively for all resources.
// Additional examples include
// - Memory using unique_ptr and shared_ptr
// - Containers - the standard library linked list,
//   vector (i.e. self-resizing array), hash maps, and so on
//   all automatically destroy their contents when they fall out of scope.
// - Mutexes using lock_guard and unique_lock
// Out:
// input_line_71:14:5: error: use of undeclared identifier 'doSomethingWithTheFile'; did you mean 'doSomethingWithAFile'?
//     doSomethingWithTheFile(fh);
//     ^~~~~~~~~~~~~~~~~~~~~~
//     doSomethingWithAFile
// input_line_71:10:6: note: 'doSomethingWithAFile' declared here
// void doSomethingWithAFile(const char* filename)
//      ^
// input_line_71:14:28: error: cannot initialize a parameter of type 'const char *' with an lvalue of type 'FILE *' (aka '_IO_FILE *')
//     doSomethingWithTheFile(fh);
//                            ^~
// input_line_71:10:39: note: passing argument to parameter 'filename' here
// void doSomethingWithAFile(const char* filename)
//                                       ^
// input_line_71:15:5: error: use of undeclared identifier 'doSomethingElseWithIt'
//     doSomethingElseWithIt(fh);
//     ^
// input_line_71:28:1: error: function definition is not allowed here
// {
// ^
// input_line_71:46:1: error: function definition is not allowed here
// {
// ^
// input_line_71:63:1: error: function definition is not allowed here
// {
// ^
// input_line_71:83:1: error: function definition is not allowed here
// {
// ^
// Interpreter Error:

// %% [markdown]
// Smart Pointer
// ---

// %%
// Generally a smart pointer is a class which wraps a "raw pointer" (usage of "new"
// respectively malloc/calloc in C). The goal is to be able to
// manage the lifetime of the object being pointed to without ever needing to explicitly delete 
// the object. The term itself simply describes a set of pointers with the
// mentioned abstraction.
// Smart pointers should preferred over raw pointers, to prevent
// risky memory leaks, which happen if you forget to delete an object.

// Usage of a raw pointer:
Dog* ptr = new Dog();
ptr->bark();
delete ptr;

// By using a smart pointer, you don't have to worry about the deletion
// of the object anymore.
// A smart pointer describes a policy, to count the references to the
// pointer. The object gets destroyed when the last
// reference to the object gets destroyed.

// Usage of "std::shared_ptr":
void foo()
{
// It's no longer necessary to delete the Dog.
std::shared_ptr<Dog> doggo(new Dog());
doggo->bark();
}

// Beware of possible circular references!!!
// There will be always a reference, so it will be never destroyed!
std::shared_ptr<Dog> doggo_one(new Dog());
std::shared_ptr<Dog> doggo_two(new Dog());
doggo_one = doggo_two; // p1 references p2
doggo_two = doggo_one; // p2 references p1

// There are several kinds of smart pointers. 
// The way you have to use them is always the same.
// This leads us to the question: when should we use each kind of smart pointer?
// std::unique_ptr - use it when you just want to hold one reference to
// the object.
// std::shared_ptr - use it when you want to hold multiple references to the
// same object and want to make sure that it's deallocated
// when all references are gone.
// std::weak_ptr - use it when you want to access
// the underlying object of a std::shared_ptr without causing that object to stay allocated.
// Weak pointers are used to prevent circular referencing.
// Out:
// input_line_51:10:1: error: use of undeclared identifier 'Dog'; did you mean 'log'?
// Dog* ptr = new Dog();
// ^~~
// log
// /srv/conda/envs/notebook/x86_64-conda-linux-gnu/sysroot/usr/include/bits/mathcalls.h:110:13: note: 'log' declared here
// __MATHCALL (log,, (_Mdouble_ __x));
//             ^
// input_line_51:10:16: error: unknown type name 'Dog'
// Dog* ptr = new Dog();
//                ^
// input_line_51:10:6: error: use of undeclared identifier 'ptr'
// Dog* ptr = new Dog();
//      ^
// input_line_51:11:1: error: use of undeclared identifier 'ptr'; did you mean 'pmr'?
// ptr->bark();
// ^~~
// pmr
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/forward_list:50:13: note: 'pmr' declared here
//   namespace pmr
//             ^
// input_line_51:11:1: error: unexpected namespace name 'pmr': expected expression
// ptr->bark();
// ^
// input_line_51:12:8: error: use of undeclared identifier 'ptr'
// delete ptr;
//        ^
// input_line_51:20:1: error: function definition is not allowed here
// {
// ^
// input_line_51:27:17: error: use of undeclared identifier 'Dog'; did you mean 'log'?
// std::shared_ptr<Dog> doggo_one(new Dog());
//                 ^~~
//                 log
// /srv/conda/envs/notebook/x86_64-conda-linux-gnu/sysroot/usr/include/bits/mathcalls.h:110:13: note: 'log' declared here
// __MATHCALL (log,, (_Mdouble_ __x));
//             ^
// input_line_51:27:17: error: template argument for template type parameter must be a type
// std::shared_ptr<Dog> doggo_one(new Dog());
//                 ^~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/shared_ptr.h:120:21: note: template parameter is declared here
//   template<typename _Tp>
//                     ^
// input_line_51:27:36: error: unknown type name 'Dog'
// std::shared_ptr<Dog> doggo_one(new Dog());
//                                    ^
// input_line_51:28:17: error: use of undeclared identifier 'Dog'; did you mean 'log'?
// std::shared_ptr<Dog> doggo_two(new Dog());
//                 ^~~
//                 log
// /srv/conda/envs/notebook/x86_64-conda-linux-gnu/sysroot/usr/include/bits/mathcalls.h:110:13: note: 'log' declared here
// __MATHCALL (log,, (_Mdouble_ __x));
//             ^
// input_line_51:28:17: error: template argument for template type parameter must be a type
// std::shared_ptr<Dog> doggo_two(new Dog());
//                 ^~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/shared_ptr.h:120:21: note: template parameter is declared here
//   template<typename _Tp>
//                     ^
// input_line_51:28:36: error: unknown type name 'Dog'
// std::shared_ptr<Dog> doggo_two(new Dog());
//                                    ^
// Interpreter Error:

// %% [markdown]
// Containers
// ---

// %%
// Containers or the Standard Template Library are some predefined templates.
// They manage the storage space for its elements and provide
// member functions to access and manipulate them.

// Few containers are as follows:

// Vector (Dynamic array)
// Allow us to Define the Array or list of objects at run time
#include <vector>
string val;
vector<string> my_vector; // initialize the vector
cin >> val;
my_vector.push_back(val); // will push the value of 'val' into vector ("array") my_vector
my_vector.push_back(val); // will push the value into the vector again (now having two elements)

// To iterate through a vector we have 2 choices:
// Either classic looping (iterating through the vector from index 0 to its last index):
for (int i = 0; i < my_vector.size(); i++) {
    cout << my_vector[i] << endl; // for accessing a vector's element we can use the operator []
}

// or using an iterator:
vector<string>::iterator it; // initialize the iterator for vector
for (it = my_vector.begin(); it != my_vector.end(); ++it) {
    cout << *it  << endl;
}

// Set
// Sets are containers that store unique elements following a specific order.
// Set is a very useful container to store unique values in sorted order
// without any other functions or code.

#include<set>
set<int> ST;    // Will initialize the set of int data type
ST.insert(30);  // Will insert the value 30 in set ST
ST.insert(10);  // Will insert the value 10 in set ST
ST.insert(20);  // Will insert the value 20 in set ST
ST.insert(30);  // Will insert the value 30 in set ST
// Now elements of sets are as follows
//  10 20 30

// To erase an element
ST.erase(20);  // Will erase element with value 20
// Set ST: 10 30
// To iterate through Set we use iterators
set<int>::iterator it;
for(it=ST.begin();it!=ST.end();it++) {
    cout << *it << endl;
}
// Output:
// 10
// 30

// To clear the complete container we use Container_name.clear()
ST.clear();
cout << ST.size();  // will print the size of set ST
// Output: 0

// NOTE: for duplicate elements we can use multiset
// NOTE: For hash sets, use unordered_set. They are more efficient but
// do not preserve order. unordered_set is available since C++11

// Map
// Maps store elements formed by a combination of a key value
// and a mapped value, following a specific order.

#include<map>
map<char, int> mymap;  // Will initialize the map with key as char and value as int

mymap.insert(pair<char,int>('A',1));
// Will insert value 1 for key A
mymap.insert(pair<char,int>('Z',26));
// Will insert value 26 for key Z

// To iterate
map<char,int>::iterator it;
for (it=mymap.begin(); it!=mymap.end(); ++it)
    std::cout << it->first << "->" << it->second << std::endl;
// Output:
// A->1
// Z->26

// To find the value corresponding to a key
it = mymap.find('Z');
cout << it->second;

// Output: 26

// NOTE: For hash maps, use unordered_map. They are more efficient but do
// not preserve order. unordered_map is available since C++11.

// Containers with object keys of non-primitive values (custom classes) require
// compare function in the object itself or as a function pointer. Primitives
// have default comparators, but you can override it.
class Foo {
public:
    int j;
    Foo(int a) : j(a) {}
};
struct compareFunction {
    bool operator()(const Foo& a, const Foo& b) const {
        return a.j < b.j;
    }
};
// this isn't allowed (although it can vary depending on compiler)
// std::map<Foo, int> fooMap;
std::map<Foo, int, compareFunction> fooMap;
fooMap[Foo(1)]  = 1;
fooMap.find(Foo(1)); //true
// Out:
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::__not_<std::is_lvalue_reference<std::basic_istream<char> &> >'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/istream:974:24: note: in instantiation of template class 'std::__and_<std::__not_<std::is_lvalue_reference<std::basic_istream<char> &> >, std::__is_convertible_to_basic_istream<std::basic_istream<char> &>, std::__is_extractable<std::basic_istream<char> &, std::__cxx11::basic_string<char> &, void> >' requested here
//     typename enable_if<__and_<__not_<is_lvalue_reference<_Istream>>,
//                        ^
// input_line_55:4:5: note: while substituting deduced template arguments into function template 'operator>>' [with _Istream = std::basic_istream<char> &, _Tp = std::__cxx11::basic_string<char> &]
// cin >> val;
//     ^
// input_line_55:10:29: error: reference to overloaded function could not be resolved; did you mean to call it?
//     cout << my_vector[i] << endl; // for accessing a vector's element we can use the operator []
//                             ^~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:681:5: note: possible target for call
//     endl(basic_ostream<_CharT, _Traits>& __os)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/string_view:621:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'basic_string_view<char, std::char_traits<char> >' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/system_error:262:5: note: candidate function template not viable: no overload of 'endl' matching 'const std::error_code' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const error_code& __e)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:117:7: note: candidate function not viable: no overload of 'endl' matching 'std::basic_ostream<char, std::char_traits<char> >::__ios_type &(*)(std::basic_ostream<char, std::char_traits<char> >::__ios_type &)' (aka 'basic_ios<char, std::char_traits<char> > &(*)(basic_ios<char, std::char_traits<char> > &)') for 1st argument
//       operator<<(__ios_type& (*__pf)(__ios_type&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:127:7: note: candidate function not viable: no overload of 'endl' matching 'std::ios_base &(*)(std::ios_base &)' for 1st argument
//       operator<<(ios_base& (*__pf) (ios_base&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:166:7: note: candidate function not viable: no overload of 'endl' matching 'long' for 1st argument
//       operator<<(long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:170:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned long' for 1st argument
//       operator<<(unsigned long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:174:7: note: candidate function not viable: no overload of 'endl' matching 'bool' for 1st argument
//       operator<<(bool __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:178:7: note: candidate function not viable: no overload of 'endl' matching 'short' for 1st argument
//       operator<<(short __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:181:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned short' for 1st argument
//       operator<<(unsigned short __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:189:7: note: candidate function not viable: no overload of 'endl' matching 'int' for 1st argument
//       operator<<(int __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:192:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned int' for 1st argument
//       operator<<(unsigned int __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:201:7: note: candidate function not viable: no overload of 'endl' matching 'long long' for 1st argument
//       operator<<(long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:205:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned long long' for 1st argument
//       operator<<(unsigned long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:220:7: note: candidate function not viable: no overload of 'endl' matching 'double' for 1st argument
//       operator<<(double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:224:7: note: candidate function not viable: no overload of 'endl' matching 'float' for 1st argument
//       operator<<(float __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:232:7: note: candidate function not viable: no overload of 'endl' matching 'long double' for 1st argument
//       operator<<(long double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:250:7: note: candidate function not viable: no overload of 'endl' matching 'std::nullptr_t' (aka 'nullptr_t') for 1st argument
//       operator<<(nullptr_t)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:276:7: note: candidate function not viable: no overload of 'endl' matching 'std::basic_ostream<char, std::char_traits<char> >::__streambuf_type *' (aka 'basic_streambuf<char, std::char_traits<char> > *') for 1st argument
//       operator<<(__streambuf_type* __sb);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:506:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, _CharT __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:511:5: note: candidate function template not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:517:5: note: candidate function template not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:523:5: note: candidate function template not viable: no overload of 'endl' matching 'signed char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, signed char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:528:5: note: candidate function template not viable: no overload of 'endl' matching 'unsigned char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, unsigned char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:589:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const _CharT* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:606:5: note: candidate function template not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:619:5: note: candidate function template not viable: no overload of 'endl' matching 'const signed char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const signed char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:624:5: note: candidate function template not viable: no overload of 'endl' matching 'const unsigned char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const unsigned char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/ostream.tcc:321:5: note: candidate function template not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:6480:5: note: candidate template ignored: couldn't infer template argument '_Alloc'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/cstddef:125:5: note: candidate template ignored: couldn't infer template argument '_IntegerType'
//     operator<<(byte __b, _IntegerType __shift) noexcept
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/shared_ptr.h:69:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(std::basic_ostream<_Ch, _Tr>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: couldn't infer template argument '_Dom'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:370:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const typename _Dom::value_type& __t,                  \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: couldn't infer template argument '_Dom'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:396:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const valarray<typename _Dom::value_type>& __v,        \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: couldn't infer template argument '_Tp'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1177:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const typename valarray<_Tp>::value_type& __t,         \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:773:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(_Ostream&& __os, const _Tp& __x)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/complex:554:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const complex<_Tp>& __x)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:344:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom1, typename _Dom1::value_type>& __v,   \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:357:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom, typename _Dom::value_type>& __v,     \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:383:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom,typename _Dom::value_type>& __e,      \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1155:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v, const valarray<_Tp>& __w)    \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1166:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v,                              \
//     ^
// input_line_55:15:21: error: reference to overloaded function could not be resolved; did you mean to call it?
//     cout << *it  << endl;
//                     ^~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:681:5: note: possible target for call
//     endl(basic_ostream<_CharT, _Traits>& __os)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/string_view:621:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'basic_string_view<char, std::char_traits<char> >' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/system_error:262:5: note: candidate function template not viable: no overload of 'endl' matching 'const std::error_code' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const error_code& __e)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:117:7: note: candidate function not viable: no overload of 'endl' matching 'std::basic_ostream<char, std::char_traits<char> >::__ios_type &(*)(std::basic_ostream<char, std::char_traits<char> >::__ios_type &)' (aka 'basic_ios<char, std::char_traits<char> > &(*)(basic_ios<char, std::char_traits<char> > &)') for 1st argument
//       operator<<(__ios_type& (*__pf)(__ios_type&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:127:7: note: candidate function not viable: no overload of 'endl' matching 'std::ios_base &(*)(std::ios_base &)' for 1st argument
//       operator<<(ios_base& (*__pf) (ios_base&))
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:166:7: note: candidate function not viable: no overload of 'endl' matching 'long' for 1st argument
//       operator<<(long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:170:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned long' for 1st argument
//       operator<<(unsigned long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:174:7: note: candidate function not viable: no overload of 'endl' matching 'bool' for 1st argument
//       operator<<(bool __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:178:7: note: candidate function not viable: no overload of 'endl' matching 'short' for 1st argument
//       operator<<(short __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:181:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned short' for 1st argument
//       operator<<(unsigned short __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:189:7: note: candidate function not viable: no overload of 'endl' matching 'int' for 1st argument
//       operator<<(int __n);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:192:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned int' for 1st argument
//       operator<<(unsigned int __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:201:7: note: candidate function not viable: no overload of 'endl' matching 'long long' for 1st argument
//       operator<<(long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:205:7: note: candidate function not viable: no overload of 'endl' matching 'unsigned long long' for 1st argument
//       operator<<(unsigned long long __n)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:220:7: note: candidate function not viable: no overload of 'endl' matching 'double' for 1st argument
//       operator<<(double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:224:7: note: candidate function not viable: no overload of 'endl' matching 'float' for 1st argument
//       operator<<(float __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:232:7: note: candidate function not viable: no overload of 'endl' matching 'long double' for 1st argument
//       operator<<(long double __f)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:250:7: note: candidate function not viable: no overload of 'endl' matching 'std::nullptr_t' (aka 'nullptr_t') for 1st argument
//       operator<<(nullptr_t)
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:276:7: note: candidate function not viable: no overload of 'endl' matching 'std::basic_ostream<char, std::char_traits<char> >::__streambuf_type *' (aka 'basic_streambuf<char, std::char_traits<char> > *') for 1st argument
//       operator<<(__streambuf_type* __sb);
//       ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:506:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, _CharT __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:511:5: note: candidate function template not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:517:5: note: candidate function template not viable: no overload of 'endl' matching 'char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:523:5: note: candidate function template not viable: no overload of 'endl' matching 'signed char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, signed char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:528:5: note: candidate function template not viable: no overload of 'endl' matching 'unsigned char' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, unsigned char __c)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:589:5: note: candidate function [with _CharT = char, _Traits = std::char_traits<char>] not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const _CharT* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:606:5: note: candidate function template not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:619:5: note: candidate function template not viable: no overload of 'endl' matching 'const signed char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const signed char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:624:5: note: candidate function template not viable: no overload of 'endl' matching 'const unsigned char *' for 2nd argument
//     operator<<(basic_ostream<char, _Traits>& __out, const unsigned char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/ostream.tcc:321:5: note: candidate function template not viable: no overload of 'endl' matching 'const char *' for 2nd argument
//     operator<<(basic_ostream<_CharT, _Traits>& __out, const char* __s)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/basic_string.h:6480:5: note: candidate template ignored: couldn't infer template argument '_Alloc'
//     operator<<(basic_ostream<_CharT, _Traits>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/cstddef:125:5: note: candidate template ignored: couldn't infer template argument '_IntegerType'
//     operator<<(byte __b, _IntegerType __shift) noexcept
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/shared_ptr.h:69:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(std::basic_ostream<_Ch, _Tr>& __os,
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: couldn't infer template argument '_Dom'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:370:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const typename _Dom::value_type& __t,                  \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: couldn't infer template argument '_Dom'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:396:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const valarray<typename _Dom::value_type>& __v,        \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: couldn't infer template argument '_Tp'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1177:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const typename valarray<_Tp>::value_type& __t,         \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/ostream:773:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(_Ostream&& __os, const _Tp& __x)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/complex:554:5: note: candidate template ignored: couldn't infer template argument '_Tp'
//     operator<<(basic_ostream<_CharT, _Traits>& __os, const complex<_Tp>& __x)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
//     _DEFINE_EXPR_BINARY_OPERATOR(<<, struct std::__shift_left)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:344:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom1, typename _Dom1::value_type>& __v,   \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:357:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom, typename _Dom::value_type>& __v,     \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:413:5: note: candidate template ignored: could not match '_Expr' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/valarray_after.h:383:5: note: expanded from macro '_DEFINE_EXPR_BINARY_OPERATOR'
//     operator _Op(const _Expr<_Dom,typename _Dom::value_type>& __e,      \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// _DEFINE_BINARY_OPERATOR(<<, __shift_left)
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1155:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v, const valarray<_Tp>& __w)    \
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1193:1: note: candidate template ignored: could not match 'valarray' against 'basic_ostream'
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/valarray:1166:5: note: expanded from macro '_DEFINE_BINARY_OPERATOR'
//     operator _Op(const valarray<_Tp>& __v,                              \
//     ^
// Interpreter Error:

// %% [markdown]
// Lambda Expressions (C++11 and above)
// ---

// %%
// lambdas are a convenient way of defining an anonymous function
// object right at the location where it is invoked or passed as
// an argument to a function.

// For example, consider sorting a vector of pairs using the second
// value of the pair

vector<pair<int, int> > tester;
tester.push_back(make_pair(3, 6));
tester.push_back(make_pair(1, 9));
tester.push_back(make_pair(5, 0));

// Pass a lambda expression as third argument to the sort function
// sort is from the <algorithm> header

sort(tester.begin(), tester.end(), [](const pair<int, int>& lhs, const pair<int, int>& rhs) {
        return lhs.second < rhs.second;
    });

// Notice the syntax of the lambda expression,
// [] in the lambda is used to "capture" variables
// The "Capture List" defines what from the outside of the lambda should be available inside the function body and how.
// It can be either:
//     1. a value : [x]
//     2. a reference : [&x]
//     3. any variable currently in scope by reference [&]
//     4. same as 3, but by value [=]
// Example:

vector<int> dog_ids;
// number_of_dogs = 3;
for(int i = 0; i < 3; i++) {
    dog_ids.push_back(i);
}

int weight[3] = {30, 50, 10};

// Say you want to sort dog_ids according to the dogs' weights
// So dog_ids should in the end become: [2, 0, 1]

// Here's where lambda expressions come in handy

sort(dog_ids.begin(), dog_ids.end(), [&weight](const int &lhs, const int &rhs) {
        return weight[lhs] < weight[rhs];
    });
// Note we captured "weight" by reference in the above example.
// More on Lambdas in C++ : https://stackoverflow.com/questions/7627098/what-is-a-lambda-expression-in-c11
// Out:
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:401:66: error: no member named 'value' in 'std::is_same<std::pair<int, int>, std::pair<int, int> >'
//       static_assert(is_same<typename remove_cv<_Tp>::type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// input_line_56:7:25: note: in instantiation of template class 'std::vector<std::pair<int, int>, std::allocator<std::pair<int, int> > >' requested here
// vector<pair<int, int> > tester;
//                         ^
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:404:64: error: no member named 'value' in 'std::is_same<std::pair<int, int>, std::pair<int, int> >'
//       static_assert(is_same<typename _Alloc::value_type, _Tp>::value,
//                     ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:116:31: error: no member named 'value' in 'std::is_lvalue_reference<std::allocator<std::pair<int, int> > >'
//     : public conditional<_B1::value, _B1, _B2>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:528:14: note: in instantiation of template class 'std::__or_<std::is_lvalue_reference<std::allocator<std::pair<int, int> > >, std::is_rvalue_reference<std::allocator<std::pair<int, int> > > >' requested here
//     : public __or_<is_lvalue_reference<_Tp>,
//              ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:26: note: in instantiation of template class 'std::is_reference<std::allocator<std::pair<int, int> > >' requested here
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:206:24: note: in instantiation of template class 'std::__or_<std::is_reference<std::allocator<std::pair<int, int> > >, std::is_function<std::allocator<std::pair<int, int> > >, std::is_void<std::allocator<std::pair<int, int> > >, std::__is_array_unknown_bounds<std::allocator<std::pair<int, int> > > >' requested here
//     constexpr typename __or_<
//                        ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1020:21: note: while substituting deduced template arguments into function template '__is_complete_or_unbounded' [with _TypeIdentity = std::__type_identity<std::allocator<std::pair<int, int> > >, _NestedType = (no value)]
//       static_assert(std::__is_complete_or_unbounded(__type_identity<_Tp>{}),
//                     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:132:6: note: in instantiation of template class 'std::is_nothrow_default_constructible<std::allocator<std::pair<int, int> > >' requested here
//             is_nothrow_default_constructible<_Tp_alloc_type>::value)
//             ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:340:20: note: in instantiation of exception specification for '_Vector_impl' requested here
//       _Vector_impl _M_impl;
//                    ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:389:30: note: in evaluation of exception specification for 'std::_Vector_base<std::pair<int, int>, std::allocator<std::pair<int, int> > >::_Vector_base' needed here
//     class vector : protected _Vector_base<_Tp, _Alloc>
//                              ^
// input_line_56:7:25: note: in evaluation of exception specification for 'std::vector<std::pair<int, int>, std::allocator<std::pair<int, int> > >::vector' needed here
// vector<pair<int, int> > tester;
//                         ^
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:62:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/vector:67:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:132:56: error: no member named 'value' in 'std::is_nothrow_default_constructible<std::allocator<std::pair<int, int> > >'
//             is_nothrow_default_constructible<_Tp_alloc_type>::value)
//             ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/x86_64-conda-linux-gnu/bits/c++config.h:171:46: note: expanded from macro '_GLIBCXX_NOEXCEPT_IF'
// #  define _GLIBCXX_NOEXCEPT_IF(...) noexcept(__VA_ARGS__)
//                                              ^~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:340:20: note: in instantiation of exception specification for '_Vector_impl' requested here
//       _Vector_impl _M_impl;
//                    ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_vector.h:389:30: note: in evaluation of exception specification for 'std::_Vector_base<std::pair<int, int>, std::allocator<std::pair<int, int> > >::_Vector_base' needed here
//     class vector : protected _Vector_base<_Tp, _Alloc>
//                              ^
// input_line_56:7:25: note: in evaluation of exception specification for 'std::vector<std::pair<int, int>, std::allocator<std::pair<int, int> > >::vector' needed here
// vector<pair<int, int> > tester;
//                         ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2128:36: error: no member named 'value' in 'std::is_array<int>'
//            bool _IsArray = is_array<_Up>::value,
//                            ~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2152:24: note: in instantiation of default argument for '__decay_selector<int>' required here
//       typedef typename __decay_selector<__remove_type>::__type type;
//                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2157:5: note: in instantiation of template class 'std::decay<int>' requested here
//     using __decay_t = typename decay<_Tp>::type;
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2176:5: note: in instantiation of template type alias '__decay_t' requested here
//     using __decay_and_strip = __strip_reference_wrapper<__decay_t<_Tp>>;
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:565:29: note: in instantiation of template type alias '__decay_and_strip' requested here
//     constexpr pair<typename __decay_and_strip<_T1>::__type,
//                             ^
// input_line_56:8:18: note: while substituting deduced template arguments into function template 'make_pair' [with _T1 = int, _T2 = int]
// tester.push_back(make_pair(3, 6));
//                  ^
// input_line_56:8:18: error: no matching function for call to 'make_pair'
// tester.push_back(make_pair(3, 6));
//                  ^~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:567:5: note: candidate template ignored: substitution failure [with _T1 = int, _T2 = int]
//     make_pair(_T1&& __x, _T2&& __y)
//     ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1076:58: error: no member named 'value' in 'std::__is_referenceable<int, void>'
//   template<typename _Tp, bool = __is_referenceable<_Tp>::value>
//                                 ~~~~~~~~~~~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1091:14: note: in instantiation of default argument for '__is_copy_assignable_impl<int>' required here
//     : public __is_copy_assignable_impl<_Tp>::type
//              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:26: note: in instantiation of template class 'std::is_copy_assignable<int>' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:391:3: note: in instantiation of template class 'std::__and_<std::is_copy_assignable<int>, std::is_copy_assignable<int> >' requested here
//                 __and_<is_copy_assignable<_T1>,
//                 ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:567:5: note: in instantiation of template class 'std::pair<int, int>' requested here
//     make_pair(_T1&& __x, _T2&& __y)
//     ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:116:31: error: no member named 'value' in 'std::is_lvalue_reference<int>'
//     : public conditional<_B1::value, _B1, _B2>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:528:14: note: in instantiation of template class 'std::__or_<std::is_lvalue_reference<int>, std::is_rvalue_reference<int> >' requested here
//     : public __or_<is_lvalue_reference<_Tp>,
//              ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:26: note: in instantiation of template class 'std::is_reference<int>' requested here
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:206:24: note: in instantiation of template class 'std::__or_<std::is_reference<int>, std::is_function<int>, std::is_void<int>, std::__is_array_unknown_bounds<int> >' requested here
//     constexpr typename __or_<
//                        ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1093:21: note: while substituting deduced template arguments into function template '__is_complete_or_unbounded' [with _TypeIdentity = std::__type_identity<int>, _NestedType = (no value)]
//       static_assert(std::__is_complete_or_unbounded(__type_identity<_Tp>{}),
//                     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:26: note: in instantiation of template class 'std::is_copy_assignable<int>' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:391:3: note: in instantiation of template class 'std::__and_<std::is_copy_assignable<int>, std::is_copy_assignable<int> >' requested here
//                 __and_<is_copy_assignable<_T1>,
//                 ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:567:5: note: in instantiation of template class 'std::pair<int, int>' requested here
//     make_pair(_T1&& __x, _T2&& __y)
//     ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1097:58: error: no member named 'value' in 'std::__is_referenceable<int, void>'
//   template<typename _Tp, bool = __is_referenceable<_Tp>::value>
//                                 ~~~~~~~~~~~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1112:14: note: in instantiation of default argument for '__is_move_assignable_impl<int>' required here
//     : public __is_move_assignable_impl<_Tp>::type
//              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:26: note: in instantiation of template class 'std::is_move_assignable<int>' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:402:3: note: in instantiation of template class 'std::__and_<std::is_move_assignable<int>, std::is_move_assignable<int> >' requested here
//                 __and_<is_move_assignable<_T1>,
//                 ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:567:5: note: in instantiation of template class 'std::pair<int, int>' requested here
//     make_pair(_T1&& __x, _T2&& __y)
//     ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:31: error: no member named 'value' in 'std::is_constructible<int, const int &>'
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:106:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, const int &>, std::is_constructible<int, const int &> >' requested here
//         return __and_<is_constructible<_T1, const _U1&>,
//                ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:262:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_ConstructiblePair<int, int>' requested here
//                            _ConstructiblePair<_U1, _U2>()
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:266:17: note: while substituting prior template arguments into non-type template parameter [with _U1 = int, _U2 = int]
//       constexpr pair(const _T1& __a, const _T2& __b)
//                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = (no value), _U2 = (no value), $2 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:31: error: no member named 'value' in 'std::is_void<const int &>'
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1416:19: note: in instantiation of template class 'std::__or_<std::is_void<const int &>, std::is_function<int>, std::is_array<int> >' requested here
//            bool = __or_<is_void<_From>, is_function<_To>,
//                   ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1448:14: note: in instantiation of default argument for '__is_convertible_helper<const int &, int>' required here
//     : public __is_convertible_helper<_From, _To>::type
//              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:26: note: in instantiation of template class 'std::is_convertible<const int &, int>' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:113:9: note: in instantiation of template class 'std::__and_<std::is_convertible<const int &, int>, std::is_convertible<const int &, int> >' requested here
//         return __and_<is_convertible<const _U1&, _T1>,
//                ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:264:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_ImplicitlyConvertiblePair<int, int>' requested here
//                            _ImplicitlyConvertiblePair<_U1, _U2>(),
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:266:17: note: while substituting prior template arguments into non-type template parameter [with _U1 = int, _U2 = int]
//       constexpr pair(const _T1& __a, const _T2& __b)
//                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = (no value), _U2 = (no value), $2 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::is_constructible<int, int &&>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:153:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, int &&>, std::is_constructible<int, const int &&>, std::__and_<std::is_convertible<int &&, int>, std::is_convertible<const int &, int> > >' requested here
//         return __and_<is_constructible<_T1, _U1&&>,
//                ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:320:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_MoveCopyPair<true, int, int>' requested here
//                            _MoveCopyPair<true, _U1, _T2>(),
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:322:18: note: while substituting prior template arguments into non-type template parameter [with _U1 = int]
//        constexpr pair(_U1&& __x, const _T2& __y)
//                  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = int, $1 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::is_constructible<int, int &&>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:153:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, int &&>, std::is_constructible<int, const int &&>, std::__not_<std::__and_<std::is_convertible<int &&, int>, std::is_convertible<const int &, int> > > >' requested here
//         return __and_<is_constructible<_T1, _U1&&>,
//                ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:327:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_MoveCopyPair<false, int, int>' requested here
//                            _MoveCopyPair<false, _U1, _T2>(),
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:329:27: note: while substituting prior template arguments into non-type template parameter [with _U1 = int]
//        explicit constexpr pair(_U1&& __x, const _T2& __y)
//                           ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = int, $1 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::is_constructible<int, const int &>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:139:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, const int &>, std::is_constructible<int, int &&>, std::__and_<std::is_convertible<const int &, int>, std::is_convertible<int &&, int> > >' requested here
//         return __and_<is_constructible<_T1, const _U1&>,
//                ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:334:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_CopyMovePair<true, int, int>' requested here
//                            _CopyMovePair<true, _T1, _U2>(),
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:336:18: note: while substituting prior template arguments into non-type template parameter [with _U2 = int]
//        constexpr pair(const _T1& __x, _U2&& __y)
//                  ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U2 = int, $1 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::is_constructible<int, const int &>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:139:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, const int &>, std::is_constructible<int, int &&>, std::__not_<std::__and_<std::is_convertible<const int &, int>, std::is_convertible<int &&, int> > > >' requested here
//         return __and_<is_constructible<_T1, const _U1&>,
//                ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:341:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_CopyMovePair<false, int, int>' requested here
//                            _CopyMovePair<false, _T1, _U2>(),
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:343:17: note: while substituting prior template arguments into non-type template parameter [with _U2 = int]
//        explicit pair(const _T1& __x, _U2&& __y)
//                 ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U2 = int, $1 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:31: error: no member named 'value' in 'std::is_constructible<int, int &&>'
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:120:9: note: in instantiation of template class 'std::__and_<std::is_constructible<int, int &&>, std::is_constructible<int, int &&> >' requested here
//         return __and_<is_constructible<_T1, _U1&&>,
//                ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:348:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_MoveConstructiblePair<int, int>' requested here
//                            _MoveConstructiblePair<_U1, _U2>()
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:352:12: note: while substituting prior template arguments into non-type template parameter [with _U1 = int, _U2 = int]
//         constexpr pair(_U1&& __x, _U2&& __y)
//                   ^~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = int, _U2 = int, $2 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:31: error: no member named 'value' in 'std::is_void<int &&>'
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1416:19: note: in instantiation of template class 'std::__or_<std::is_void<int &&>, std::is_function<int>, std::is_array<int> >' requested here
//            bool = __or_<is_void<_From>, is_function<_To>,
//                   ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1448:14: note: in instantiation of default argument for '__is_convertible_helper<int &&, int>' required here
//     : public __is_convertible_helper<_From, _To>::type
//              ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:26: note: in instantiation of template class 'std::is_convertible<int &&, int>' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:127:9: note: in instantiation of template class 'std::__and_<std::is_convertible<int &&, int>, std::is_convertible<int &&, int> >' requested here
//         return __and_<is_convertible<_U1&&, _T1>,
//                ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:350:7: note: in instantiation of function template specialization 'std::_PCC<true, int, int>::_ImplicitlyMoveConvertiblePair<int, int>' requested here
//                            _ImplicitlyMoveConvertiblePair<_U1, _U2>(),
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:352:12: note: while substituting prior template arguments into non-type template parameter [with _U1 = int, _U2 = int]
//         constexpr pair(_U1&& __x, _U2&& __y)
//                   ^~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: note: while substituting deduced template arguments into function template 'pair' [with _U1 = int, _U2 = int, $2 = (no value)]
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:38:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/utility:70:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:572:14: error: no matching constructor for initialization of '__pair_type' (aka 'pair<int, int>')
//       return __pair_type(std::forward<_T1>(__x), std::forward<_T2>(__y));
//              ^           ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// input_line_56:9:18: note: in instantiation of function template specialization 'std::make_pair<int, int>' requested here
// tester.push_back(make_pair(1, 9));
//                  ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:266:17: note: candidate template ignored: substitution failure [with _U1 = int, _U2 = int]: non-type template argument is not a constant expression
//       constexpr pair(const _T1& __a, const _T2& __b)
//                 ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:276:26: note: candidate template ignored: substitution failure [with _U1 = int, _U2 = int]: no matching function for call to '_ConstructiblePair'
//       explicit constexpr pair(const _T1& __a, const _T2& __b)
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:322:18: note: candidate template ignored: substitution failure [with _U1 = int]: non-type template argument is not a constant expression
//        constexpr pair(_U1&& __x, const _T2& __y)
//                  ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:329:27: note: candidate template ignored: substitution failure [with _U1 = int]: non-type template argument is not a constant expression
//        explicit constexpr pair(_U1&& __x, const _T2& __y)
//                           ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:336:18: note: candidate template ignored: substitution failure [with _U2 = int]: non-type template argument is not a constant expression
//        constexpr pair(const _T1& __x, _U2&& __y)
//                  ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:343:17: note: candidate template ignored: substitution failure [with _U2 = int]: non-type template argument is not a constant expression
//        explicit pair(const _T1& __x, _U2&& __y)
//                 ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:352:12: note: candidate template ignored: substitution failure [with _U1 = int, _U2 = int]: non-type template argument is not a constant expression
//         constexpr pair(_U1&& __x, _U2&& __y)
//                   ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:361:21: note: candidate template ignored: substitution failure [with _U1 = int, _U2 = int]: no matching function for call to '_MoveConstructiblePair'
//         explicit constexpr pair(_U1&& __x, _U2&& __y)
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:232:26: note: candidate constructor template not viable: requires 0 arguments, but 2 were provided
//       _GLIBCXX_CONSTEXPR pair()
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:245:26: note: candidate constructor template not viable: requires 0 arguments, but 2 were provided
//       explicit constexpr pair()
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:300:19: note: candidate constructor template not viable: requires single argument '__p', but 2 arguments were provided
//         constexpr pair(const pair<_U1, _U2>& __p)
//                   ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:309:21: note: candidate constructor template not viable: requires single argument '__p', but 2 arguments were provided
//         explicit constexpr pair(const pair<_U1, _U2>& __p)
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:371:12: note: candidate constructor template not viable: requires single argument '__p', but 2 arguments were provided
//         constexpr pair(pair<_U1, _U2>&& __p)
//                   ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:381:21: note: candidate constructor template not viable: requires single argument '__p', but 2 arguments were provided
//         explicit constexpr pair(pair<_U1, _U2>&& __p)
//                            ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:387:9: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         pair(piecewise_construct_t, tuple<_Args1...>, tuple<_Args2...>);
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:452:9: note: candidate constructor template not viable: requires 4 arguments, but 2 were provided
//         pair(tuple<_Args1...>&, tuple<_Args2...>&,
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:314:17: note: candidate constructor not viable: requires 1 argument, but 2 were provided
//       constexpr pair(const pair&) = default;    ///< Copy constructor
//                 ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:315:17: note: candidate constructor not viable: requires 1 argument, but 2 were provided
//       constexpr pair(pair&&) = default;         ///< Move constructor
//                 ^
// input_line_56:10:18: error: no matching function for call to 'make_pair'
// tester.push_back(make_pair(5, 0));
//                  ^~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_pair.h:567:5: note: candidate template ignored: substitution failure [with _T1 = int, _T2 = int]
//     make_pair(_T1&& __x, _T2&& __y)
//     ^
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// Interpreter Error:
// ERROR: received unknown message
// Message type: usage_request

// %%
///////////////////////////////
// Range For (C++11 and above)
///////////////////////////////

// You can use a range for loop to iterate over a container
int arr[] = {1, 10, 3};

for(int elem: arr){
    cout << elem << endl;
}

// You can use "auto" and not worry about the type of the elements of the container
// For example:

for(auto elem: arr) {
    // Do something with each element of arr
}
// Out:
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:65:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/stl_algo.h:4887:5: error: function 'std::sort<__gnu_cxx::__normal_iterator<std::pair<int, int> *, std::vector<std::pair<int, int>, std::allocator<std::pair<int, int> > > >, (lambda)>' is used but not defined in this translation unit, and cannot be defined in any other translation unit because its type does not have linkage
//     sort(_RandomAccessIterator __first, _RandomAccessIterator __last,
//     ^
// fatal error: cannot open file 'input_line_76': No such file or directory
// note: used here
// Interpreter Error:

// %% [markdown]
// Fun stuff
// ---

// %%
// Aspects of C++ that may be surprising to newcomers (and even some veterans).
// This section is, unfortunately, wildly incomplete; C++ is one of the easiest
// languages with which to shoot yourself in the foot.

// You can override private methods!
class Foo {
  virtual void bar();
};
class FooSub : public Foo {
  virtual void bar();  // Overrides Foo::bar!
};


// 0 == false == NULL (most of the time)!
bool* pt = new bool;
*pt = 0; // Sets the value points by 'pt' to false.
pt = 0;  // Sets 'pt' to the null pointer. Both lines compile without warnings.

// nullptr is supposed to fix some of that issue:
int* pt2 = new int;
*pt2 = nullptr; // Doesn't compile
pt2 = nullptr;  // Sets pt2 to null.

// There is an exception made for bools.
// This is to allow you to test for null pointers with if(!ptr),
// but as a consequence you can assign nullptr to a bool directly!
*pt = nullptr;  // This still compiles, even though '*pt' is a bool!


// '=' != '=' != '='!
// Calls Foo::Foo(const Foo&) or some variant (see move semantics) copy
// constructor.
Foo f2;
Foo f1 = f2;

// Calls Foo::Foo(const Foo&) or variant, but only copies the 'Foo' part of
// 'fooSub'. Any extra members of 'fooSub' are discarded. This sometimes
// horrifying behavior is called "object slicing."
FooSub fooSub;
Foo f1 = fooSub;

// Calls Foo::operator=(Foo&) or variant.
Foo f1;
f1 = f2;

// %% [markdown]
// Tuples (C++11 and above)
// ---

// %%
#include<tuple>

// Conceptually, Tuples are similar to old data structures (C-like structs)
// but instead of having named data members,
// its elements are accessed by their order in the tuple.

// We start with constructing a tuple.
// Packing values into tuple
auto first = make_tuple(10, 'A');
const int maxN = 1e9;
const int maxL = 15;
auto second = make_tuple(maxN, maxL);

// Printing elements of 'first' tuple
cout << get<0>(first) << " " << get<1>(first) << '\n'; //prints : 10 A

// Printing elements of 'second' tuple
cout << get<0>(second) << " " << get<1>(second) << '\n'; // prints: 1000000000 15

// Unpacking tuple into variables

int first_int;
char first_char;
tie(first_int, first_char) = first;
cout << first_int << " " << first_char << '\n';  // prints : 10 A

// We can also create tuple like this.

tuple<int, char, double> third(11, 'A', 3.14141);
// tuple_size returns number of elements in a tuple (as a constexpr)

cout << tuple_size<decltype(third)>::value << '\n'; // prints: 3

// tuple_cat concatenates the elements of all the tuples in the same order.

auto concatenated_tuple = tuple_cat(first, second, third);
// concatenated_tuple becomes = (10, 'A', 1e9, 15, 11, 'A', 3.14141)

cout << get<0>(concatenated_tuple) << '\n'; // prints: 10
cout << get<3>(concatenated_tuple) << '\n'; // prints: 15
cout << get<5>(concatenated_tuple) << '\n'; // prints: 'A'
// Out:
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2128:36: error: no member named 'value' in 'std::is_array<char>'
//            bool _IsArray = is_array<_Up>::value,
//                            ~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2152:24: note: in instantiation of default argument for '__decay_selector<char>' required here
//       typedef typename __decay_selector<__remove_type>::__type type;
//                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2157:5: note: in instantiation of template class 'std::decay<char>' requested here
//     using __decay_t = typename decay<_Tp>::type;
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2176:5: note: in instantiation of template type alias '__decay_t' requested here
//     using __decay_and_strip = __strip_reference_wrapper<__decay_t<_Tp>>;
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1490:30: note: in instantiation of template type alias '__decay_and_strip' requested here
//     constexpr tuple<typename __decay_and_strip<_Elements>::__type...>
//                              ^
// input_line_81:7:14: note: while substituting deduced template arguments into function template 'make_tuple' [with _Elements = <int, char>]
// auto first = make_tuple(10, 'A');
//              ^
// input_line_81:7:14: error: no matching function for call to 'make_tuple'
// auto first = make_tuple(10, 'A');
//              ^~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1491:5: note: candidate template ignored: substitution failure [with _Elements = <int, char>]
//     make_tuple(_Elements&&... __args)
//     ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2128:36: error: no member named 'value' in 'std::is_array<const int>'
//            bool _IsArray = is_array<_Up>::value,
//                            ~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2152:24: note: in instantiation of default argument for '__decay_selector<const int>' required here
//       typedef typename __decay_selector<__remove_type>::__type type;
//                        ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2157:5: note: in instantiation of template class 'std::decay<const int &>' requested here
//     using __decay_t = typename decay<_Tp>::type;
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2176:5: note: in instantiation of template type alias '__decay_t' requested here
//     using __decay_and_strip = __strip_reference_wrapper<__decay_t<_Tp>>;
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1490:30: note: in instantiation of template type alias '__decay_and_strip' requested here
//     constexpr tuple<typename __decay_and_strip<_Elements>::__type...>
//                              ^
// input_line_81:10:15: note: while substituting deduced template arguments into function template 'make_tuple' [with _Elements = <const int &, const int &>]
// auto second = make_tuple(maxN, maxL);
//               ^
// input_line_81:10:15: error: no matching function for call to 'make_tuple'
// auto second = make_tuple(maxN, maxL);
//               ^~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1491:5: note: candidate template ignored: substitution failure [with _Elements = <const int &, const int &>]
//     make_tuple(_Elements&&... __args)
//     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:73:38: error: no member named 'value' in 'std::__is_empty_non_tuple<char &>'
//            bool = __empty_not_final<_Head>::value>
//                   ~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:353:15: note: in instantiation of default argument for '_Head_base<1, char &>' required here
//     : private _Head_base<_Idx, _Head>
//               ^~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:202:14: note: in instantiation of template class 'std::_Tuple_impl<1, char &>' requested here
//     : public _Tuple_impl<_Idx + 1, _Tail...>,
//              ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:904:36: note: in instantiation of template class 'std::_Tuple_impl<0, int &, char &>' requested here
//     class tuple<_T1, _T2> : public _Tuple_impl<0, _T1, _T2>
//                                    ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1632:5: note: in instantiation of template class 'std::tuple<int &, char &>' requested here
//     tie(_Elements&... __args) noexcept
//     ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:73:38: error: no member named 'value' in 'std::__is_empty_non_tuple<char &>'
//            bool = __empty_not_final<_Head>::value>
//                   ~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:357:15: note: in instantiation of default argument for '_Head_base<1, char &>' required here
//       typedef _Head_base<_Idx, _Head> _Base;
//               ^~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:202:14: note: in instantiation of template class 'std::_Tuple_impl<1, char &>' requested here
//     : public _Tuple_impl<_Idx + 1, _Tail...>,
//              ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:904:36: note: in instantiation of template class 'std::_Tuple_impl<0, int &, char &>' requested here
//     class tuple<_T1, _T2> : public _Tuple_impl<0, _T1, _T2>
//                                    ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1632:5: note: in instantiation of template class 'std::tuple<int &, char &>' requested here
//     tie(_Elements&... __args) noexcept
//     ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:73:38: error: no member named 'value' in 'std::__is_empty_non_tuple<int &>'
//            bool = __empty_not_final<_Head>::value>
//                   ~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:203:15: note: in instantiation of default argument for '_Head_base<0, int &>' required here
//       private _Head_base<_Idx, _Head>
//               ^~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:904:36: note: in instantiation of template class 'std::_Tuple_impl<0, int &, char &>' requested here
//     class tuple<_T1, _T2> : public _Tuple_impl<0, _T1, _T2>
//                                    ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1632:5: note: in instantiation of template class 'std::tuple<int &, char &>' requested here
//     tie(_Elements&... __args) noexcept
//     ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:73:38: error: no member named 'value' in 'std::__is_empty_non_tuple<int &>'
//            bool = __empty_not_final<_Head>::value>
//                   ~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:208:15: note: in instantiation of default argument for '_Head_base<0, int &>' required here
//       typedef _Head_base<_Idx, _Head> _Base;
//               ^~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:904:36: note: in instantiation of template class 'std::_Tuple_impl<0, int &, char &>' requested here
//     class tuple<_T1, _T2> : public _Tuple_impl<0, _T1, _T2>
//                                    ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1632:5: note: in instantiation of template class 'std::tuple<int &, char &>' requested here
//     tie(_Elements&... __args) noexcept
//     ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:116:31: error: no member named 'value' in 'std::is_lvalue_reference<int &>'
//     : public conditional<_B1::value, _B1, _B2>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:528:14: note: in instantiation of template class 'std::__or_<std::is_lvalue_reference<int &>, std::is_rvalue_reference<int &> >' requested here
//     : public __or_<is_lvalue_reference<_Tp>,
//              ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:26: note: in instantiation of template class 'std::is_reference<int &>' requested here
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:206:24: note: in instantiation of template class 'std::__or_<std::is_reference<int &>, std::is_function<int &>, std::is_void<int &>, std::__is_array_unknown_bounds<int &> >' requested here
//     constexpr typename __or_<
//                        ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1072:21: note: while substituting deduced template arguments into function template '__is_complete_or_unbounded' [with _TypeIdentity = std::__type_identity<int &>, _NestedType = (no value)]
//       static_assert(std::__is_complete_or_unbounded(__type_identity<_Tp>{}),
//                     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:26: note: in instantiation of template class 'std::is_assignable<int &, int &>' requested here
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:940:11: note: in instantiation of template class 'std::__and_<std::is_assignable<int &, int &>, std::is_assignable<char &, char &> >' requested here
//           return __and_<is_assignable<_T1&, _U1>,
//                  ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1190:38: note: in instantiation of function template specialization 'std::tuple<int &, char &>::__assignable<int &, char &>' requested here
//       operator=(typename conditional<__assignable<const _T1&, const _T2&>(),
//                                      ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1632:5: note: in instantiation of template class 'std::tuple<int &, char &>' requested here
//     tie(_Elements&... __args) noexcept
//     ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:139:31: error: no member named 'value' in 'std::is_assignable<int &, int &>'
//     : public conditional<_B1::value, _B2, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:940:11: note: in instantiation of template class 'std::__and_<std::is_assignable<int &, int &>, std::is_assignable<char &, char &> >' requested here
//           return __and_<is_assignable<_T1&, _U1>,
//                  ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1190:38: note: in instantiation of function template specialization 'std::tuple<int &, char &>::__assignable<int &, char &>' requested here
//       operator=(typename conditional<__assignable<const _T1&, const _T2&>(),
//                                      ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1632:5: note: in instantiation of template class 'std::tuple<int &, char &>' requested here
//     tie(_Elements&... __args) noexcept
//     ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1190:38: error: non-type template argument is not a constant expression
//       operator=(typename conditional<__assignable<const _T1&, const _T2&>(),
//                                      ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1632:5: note: in instantiation of template class 'std::tuple<int &, char &>' requested here
//     tie(_Elements&... __args) noexcept
//     ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1201:38: error: use of undeclared identifier '__assignable'
//       operator=(typename conditional<__assignable<_T1, _T2>(),
//                                      ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:938:24: note: must qualify identifier to find this declaration in dependent base class
//         static constexpr bool __assignable()
//                               ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1201:38: error: no matching function for call to '__assignable'
//       operator=(typename conditional<__assignable<_T1, _T2>(),
//                                      ^~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:938:24: note: candidate template ignored: substitution failure [with _U1 = int &, _U2 = char &]
//         static constexpr bool __assignable()
//                               ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1201:38: error: no matching function for call to '__assignable'
//       operator=(typename conditional<__assignable<_T1, _T2>(),
//                                      ^~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:938:24: note: candidate template ignored: substitution failure [with _U1 = int &, _U2 = char &]
//         static constexpr bool __assignable()
//                               ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::integral_constant<bool, true>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:485:11: note: in instantiation of template class 'std::__and_<std::integral_constant<bool, true>, std::integral_constant<bool, true>, std::is_convertible<int &, int &>, std::is_convertible<char &, char &> >' requested here
//           return __and_<is_constructible<_Types, _UTypes>...,
//                  ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:928:26: note: in instantiation of function template specialization 'std::_TupleConstraints<true, int &, char &>::__is_implicitly_constructible<int &, char &>' requested here
//           _TCC<_Cond>::template __is_implicitly_constructible<_U1, _U2>(),
//                                 ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:984:55: note: in instantiation of template type alias '_ImplicitCtor' requested here
//                _ImplicitCtor<_Dummy, const _T1&, const _T2&> = true>
//                                                              ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:986:2: note: while substituting prior template arguments into non-type template parameter [with _Dummy = true]
//         tuple(const _T1& __a1, const _T2& __a2)
//         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1633:14: note: while substituting deduced template arguments into function template 'tuple' [with _Dummy = (no value), $1 = (no value)]
//     { return tuple<_Elements&...>(__args...); }
//              ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:144:31: error: no member named 'value' in 'std::integral_constant<bool, true>'
//     : public conditional<_B1::value, __and_<_B2, _B3, _Bn...>, _B1>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:496:11: note: in instantiation of template class 'std::__and_<std::integral_constant<bool, true>, std::integral_constant<bool, true>, std::__not_<std::__and_<std::is_convertible<int &, int &>, std::is_convertible<char &, char &> > > >' requested here
//           return __and_<is_constructible<_Types, _UTypes>...,
//                  ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:934:26: note: in instantiation of function template specialization 'std::_TupleConstraints<true, int &, char &>::__is_explicitly_constructible<int &, char &>' requested here
//           _TCC<_Cond>::template __is_explicitly_constructible<_U1, _U2>(),
//                                 ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:991:55: note: in instantiation of template type alias '_ExplicitCtor' requested here
//                _ExplicitCtor<_Dummy, const _T1&, const _T2&> = false>
//                                                              ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:993:2: note: while substituting prior template arguments into non-type template parameter [with _Dummy = true]
//         tuple(const _T1& __a1, const _T2& __a2)
//         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1633:14: note: while substituting deduced template arguments into function template 'tuple' [with _Dummy = (no value), $1 = (no value)]
//     { return tuple<_Elements&...>(__args...); }
//              ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:966:60: error: no member named 'value' in 'std::is_same<int, std::allocator_arg_t>'
//         { return is_same<__remove_cvref_t<_U1>, allocator_arg_t>::value; }
//                  ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:998:24: note: in instantiation of function template specialization 'std::tuple<int &, char &>::__is_alloc_arg<int &>' requested here
//                _ImplicitCtor<!__is_alloc_arg<_U1>(), _U1, _U2> = true>
//                               ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1000:2: note: while substituting prior template arguments into non-type template parameter [with _U1 = int &, _U2 = char &]
//         tuple(_U1&& __a1, _U2&& __a2)
//         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1633:14: note: while substituting deduced template arguments into function template 'tuple' [with _U1 = int &, _U2 = char &, $2 = (no value)]
//     { return tuple<_Elements&...>(__args...); }
//              ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_1:1:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/new:41:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/exception:147:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/exception_ptr.h:43:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/bits/move.h:57:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:121:31: error: no member named 'value' in 'std::is_function<char>'
//     : public conditional<_B1::value, _B1, __or_<_B2, _B3, _Bn...>>::type
//                          ~~~~~^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:149:36: note: in instantiation of template class 'std::__or_<std::is_function<char>, std::is_reference<char>, std::is_void<char> >' requested here
//     : public __bool_constant<!bool(_Pp::value)>
//                                    ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:548:14: note: in instantiation of template class 'std::__not_<std::__or_<std::is_function<char>, std::is_reference<char>, std::is_void<char> > >' requested here
//     : public __not_<__or_<is_function<_Tp>, is_reference<_Tp>,
//              ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1076:30: note: in instantiation of template class 'std::is_object<char>' requested here
//                _ImplicitDefaultCtor<is_object<_Alloc>::value, _T1, _T2> = true>
//                                     ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1078:2: note: while substituting prior template arguments into non-type template parameter [with _Alloc = char]
//         tuple(allocator_arg_t __tag, const _Alloc& __a)
//         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1633:14: note: while substituting deduced template arguments into function template 'tuple' [with _Alloc = char, $1 = (no value)]
//     { return tuple<_Elements&...>(__args...); }
//              ^
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// In file included from input_line_5:1:
// In file included from /srv/conda/envs/notebook/include/xeus/xinterpreter.hpp:13:
// In file included from /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/functional:54:
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1633:14: error: no matching constructor for initialization of 'tuple<int &, char &>'
//     { return tuple<_Elements&...>(__args...); }
//              ^                    ~~~~~~
// input_line_81:18:1: note: in instantiation of function template specialization 'std::tie<int, char>' requested here
// tie(first_int, first_char) = first;
// ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:986:2: note: candidate template ignored: substitution failure [with _Dummy = true]: non-type template argument is not a constant expression
//         tuple(const _T1& __a1, const _T2& __a2)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:993:2: note: candidate template ignored: substitution failure [with _Dummy = true]: non-type template argument is not a constant expression
//         tuple(const _T1& __a1, const _T2& __a2)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1000:2: note: candidate template ignored: substitution failure [with _U1 = int &, _U2 = char &]: non-type template argument is not a constant expression
//         tuple(_U1&& __a1, _U2&& __a2)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1007:2: note: candidate template ignored: substitution failure [with _U1 = int &, _U2 = char &]: use of undeclared identifier '__is_alloc_arg'
//         tuple(_U1&& __a1, _U2&& __a2)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1078:2: note: candidate template ignored: substitution failure [with _Alloc = char]
//         tuple(allocator_arg_t __tag, const _Alloc& __a)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:972:2: note: candidate constructor template not viable: requires 0 arguments, but 2 were provided
//         tuple()
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:979:2: note: candidate constructor template not viable: requires 0 arguments, but 2 were provided
//         tuple()
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1018:2: note: candidate constructor template not viable: requires single argument '__in', but 2 arguments were provided
//         tuple(const tuple<_U1, _U2>& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1025:2: note: candidate constructor template not viable: requires single argument '__in', but 2 arguments were provided
//         tuple(const tuple<_U1, _U2>& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1032:2: note: candidate constructor template not viable: requires single argument '__in', but 2 arguments were provided
//         tuple(tuple<_U1, _U2>&& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1039:2: note: candidate constructor template not viable: requires single argument '__in', but 2 arguments were provided
//         tuple(tuple<_U1, _U2>&& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1046:2: note: candidate constructor template not viable: requires single argument '__in', but 2 arguments were provided
//         tuple(const pair<_U1, _U2>& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1053:2: note: candidate constructor template not viable: requires single argument '__in', but 2 arguments were provided
//         tuple(const pair<_U1, _U2>& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1060:2: note: candidate constructor template not viable: requires single argument '__in', but 2 arguments were provided
//         tuple(pair<_U1, _U2>&& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1068:2: note: candidate constructor template not viable: requires single argument '__in', but 2 arguments were provided
//         tuple(pair<_U1, _U2>&& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1084:2: note: candidate constructor template not viable: requires 4 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a,
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1092:2: note: candidate constructor template not viable: requires 4 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a,
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1099:2: note: candidate constructor template not viable: requires 4 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a, _U1&& __a1, _U2&& __a2)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1107:2: note: candidate constructor template not viable: requires 4 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a,
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1114:2: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a, const tuple& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1119:2: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a, tuple&& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1125:2: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a,
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1135:2: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a,
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1144:2: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a, tuple<_U1, _U2>&& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1152:2: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a, tuple<_U1, _U2>&& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1159:2: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a,
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1167:2: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a,
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1174:2: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a, pair<_U1, _U2>&& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1182:2: note: candidate constructor template not viable: requires 3 arguments, but 2 were provided
//         tuple(allocator_arg_t __tag, const _Alloc& __a, pair<_U1, _U2>&& __in)
//         ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1011:17: note: candidate constructor not viable: requires 1 argument, but 2 were provided
//       constexpr tuple(const tuple&) = default;
//                 ^
// /srv/conda/envs/notebook/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/tuple:1013:17: note: candidate constructor not viable: requires 1 argument, but 2 were provided
//       constexpr tuple(tuple&&) = default;
//                 ^
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// Interpreter Error:

// %% [markdown]
// Logical and Bitwise operators
// ---
// Most of the operators in C++ are same as in other languages

// %%
// Logical operators

// C++ uses Short-circuit evaluation for boolean expressions, i.e, the second argument is executed or
// evaluated only if the first argument does not suffice to determine the value of the expression

true && false // Performs **logical and** to yield false
true || false // Performs **logical or** to yield true
! true        // Performs **logical not** to yield false

// Instead of using symbols equivalent keywords can be used
true and false // Performs **logical and** to yield false
true or false  // Performs **logical or** to yield true
not true       // Performs **logical not** to yield false

// Bitwise operators

// **<<** Left Shift Operator
// << shifts bits to the left
4 << 1 // Shifts bits of 4 to left by 1 to give 8
// x << n can be thought as x * 2^n


// **>>** Right Shift Operator
// >> shifts bits to the right
4 >> 1 // Shifts bits of 4 to right by 1 to give 2
// x >> n can be thought as x / 2^n

~4    // Performs a bitwise not
4 | 3 // Performs bitwise or
4 & 3 // Performs bitwise and
4 ^ 3 // Performs bitwise xor

// Equivalent keywords are
compl 4    // Performs a bitwise not
4 bitor 3  // Performs bitwise or
4 bitand 3 // Performs bitwise and
4 xor 3    // Performs bitwise xor
// Out:
// input_line_82:9:14: error: expected ';' after expression
// true && false // Performs **logical and** to yield false
//              ^
//              ;
// input_line_82:10:14: error: expected ';' after expression
// true || false // Performs **logical or** to yield true
//              ^
//              ;
// input_line_82:11:7: error: expected ';' after expression
// ! true        // Performs **logical not** to yield false
//       ^
//       ;
// input_line_82:13:15: error: expected ';' after expression
// true and false // Performs **logical and** to yield false
//               ^
//               ;
// input_line_82:14:14: error: expected ';' after expression
// true or false  // Performs **logical or** to yield true
//              ^
//              ;
// input_line_82:15:9: error: expected ';' after expression
// not true       // Performs **logical not** to yield false
//         ^
//         ;
// input_line_82:19:7: error: expected ';' after expression
// 4 << 1 // Shifts bits of 4 to left by 1 to give 8
//       ^
//       ;
// input_line_82:23:7: error: expected ';' after expression
// 4 >> 1 // Shifts bits of 4 to right by 1 to give 2
//       ^
//       ;
// input_line_82:25:3: error: expected ';' after expression
// ~4    // Performs a bitwise not
//   ^
//   ;
// input_line_82:26:6: error: expected ';' after expression
// 4 | 3 // Performs bitwise or
//      ^
//      ;
// input_line_82:27:6: error: expected ';' after expression
// 4 & 3 // Performs bitwise and
//      ^
//      ;
// input_line_82:28:6: error: expected ';' after expression
// 4 ^ 3 // Performs bitwise xor
//      ^
//      ;
// input_line_82:30:8: error: expected ';' after expression
// compl 4    // Performs a bitwise not
//        ^
//        ;
// input_line_82:31:10: error: expected ';' after expression
// 4 bitor 3  // Performs bitwise or
//          ^
//          ;
// input_line_82:32:11: error: expected ';' after expression
// 4 bitand 3 // Performs bitwise and
//           ^
//           ;
// Interpreter Error:
